# %% [markdown]
# ## ANZ Data@ANZ Program

# %% [markdown]
# This is from www.theforage.com from the Data@ANZ program
#
# There are 5 tasks:
#
#     -Exploratory Data Analysis (Mandatory)
#     -Predictive Analytics (Mandatory)
#     -Exploring Big Data
#     -Cloud Engineering Core Skills
#     -Data Engineering Core Skills
#
# "We are looking to distill unique insights from the data that will enable us to take action. We want to know “what does all this data actually mean for us and our clients, and what should we do next?”

# %% [markdown]
# ### Some subtasks to be completed
#     - Load the transaction dataset below into an analysis tool of your choice (Excel, R, SAS, Tableau, or similar)
#
#     - Start by doing some basic checks – are there any data issues? Does the data need to be cleaned?
#
#     - Gather some interesting overall insights about the data. For example -- what is the average transaction amount? How many transactions do customers make each month, on average?
#
#     - Segment the dataset by transaction date and time. Visualise transaction volume and spending over the course of an average day or week. Consider the effect of any outliers that may distort your analysis.
#
#     - For a challenge – what insights can you draw from the location information provided in the dataset?
#
#     - Put together 2-3 slides summarising your most interesting findings to ANZ management.

# %% [markdown]
# # General analysis for cleaning the data

# %%
# Importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats
import seaborn as sns
import statsmodels.api as sm
import statistics
import datetime as dt

# %%
# Loading the provided excel file
df = pd.read_excel('ANZ_synthesised_transaction_dataset.xlsx', header = 0)

# %% [markdown]
# ### Loading the dataframe for cleaning

# %%
df.head()
# Out:
#        status  card_present_flag bpay_biller_code         account currency  \
# 0  authorized                1.0              NaN  ACC-1598451071      AUD
# 1  authorized                0.0              NaN  ACC-1598451071      AUD
# 2  authorized                1.0              NaN  ACC-1222300524      AUD
# 3  authorized                1.0              NaN  ACC-1037050564      AUD
# 4  authorized                1.0              NaN  ACC-1598451071      AUD
#
#         long_lat txn_description                           merchant_id  \
# 0  153.41 -27.95             POS  81c48296-73be-44a7-befa-d053f48ce7cd
# 1  153.41 -27.95       SALES-POS  830a451c-316e-4a6a-bf25-e37caedca49e
# 2  151.23 -33.94             POS  835c231d-8cdf-4e96-859d-e9d571760cf0
# 3  153.10 -27.66       SALES-POS  48514682-c78a-4a88-b0da-2d6302e64673
# 4  153.41 -27.95       SALES-POS  b4e02c10-0852-4273-b8fd-7b3395e32eb0
#
#    merchant_code first_name  ...  age merchant_suburb merchant_state  \
# 0            NaN      Diana  ...   26         Ashmore            QLD
# 1            NaN      Diana  ...   26          Sydney            NSW
# 2            NaN    Michael  ...   38          Sydney            NSW
# 3            NaN     Rhonda  ...   40         Buderim            QLD
# 4            NaN      Diana  ...   26   Mermaid Beach            QLD
#
#                      extraction amount                    transaction_id  \
# 0  2018-08-01T01:01:15.000+0000  16.25  a623070bfead4541a6b0fff8a09e706c
# 1  2018-08-01T01:13:45.000+0000  14.19  13270a2a902145da9db4c951e04b51b9
# 2  2018-08-01T01:26:15.000+0000   6.42  feb79e7ecd7048a5a36ec889d1a94270
# 3  2018-08-01T01:38:45.000+0000  40.90  2698170da3704fd981b15e64a006079e
# 4  2018-08-01T01:51:15.000+0000   3.25  329adf79878c4cf0aeb4188b4691c266
#
#      country     customer_id merchant_long_lat movement
# 0  Australia  CUS-2487424745     153.38 -27.99    debit
# 1  Australia  CUS-2487424745     151.21 -33.87    debit
# 2  Australia  CUS-2142601169     151.21 -33.87    debit
# 3  Australia  CUS-1614226872     153.05 -26.68    debit
# 4  Australia  CUS-2487424745     153.44 -28.06    debit
#
# [5 rows x 23 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12043 entries, 0 to 12042
# Data columns (total 23 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   status             12043 non-null  object
#  1   card_present_flag  7717 non-null   float64
#  2   bpay_biller_code   885 non-null    object
#  3   account            12043 non-null  object
#  4   currency           12043 non-null  object
#  5   long_lat           12043 non-null  object
#  6   txn_description    12043 non-null  object
#  7   merchant_id        7717 non-null   object
#  8   merchant_code      883 non-null    float64
#  9   first_name         12043 non-null  object
#  10  balance            12043 non-null  float64
#  11  date               12043 non-null  datetime64[ns]
#  12  gender             12043 non-null  object
#  13  age                12043 non-null  int64
#  14  merchant_suburb    7717 non-null   object
#  15  merchant_state     7717 non-null   object
#  16  extraction         12043 non-null  object
#  17  amount             12043 non-null  float64
#  18  transaction_id     12043 non-null  object
#  19  country            12043 non-null  object
#  20  customer_id        12043 non-null  object
#  21  merchant_long_lat  7717 non-null   object
#  22  movement           12043 non-null  object
# dtypes: datetime64[ns](1), float64(4), int64(1), object(17)
# memory usage: 2.1+ MB

# %% [markdown]
# ### Converting data types

# %%
# Changing data types float64 to float32
df[['card_present_flag', 'merchant_code', 'balance', 'amount']] = df[['card_present_flag', 'merchant_code', 'balance', 'amount'
                                                                     ]].astype('float32')

# changing int64 to int 8
df['age'] = df['age'].astype('int8')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12043 entries, 0 to 12042
# Data columns (total 23 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   status             12043 non-null  object
#  1   card_present_flag  7717 non-null   float32
#  2   bpay_biller_code   885 non-null    object
#  3   account            12043 non-null  object
#  4   currency           12043 non-null  object
#  5   long_lat           12043 non-null  object
#  6   txn_description    12043 non-null  object
#  7   merchant_id        7717 non-null   object
#  8   merchant_code      883 non-null    float32
#  9   first_name         12043 non-null  object
#  10  balance            12043 non-null  float32
#  11  date               12043 non-null  datetime64[ns]
#  12  gender             12043 non-null  object
#  13  age                12043 non-null  int8
#  14  merchant_suburb    7717 non-null   object
#  15  merchant_state     7717 non-null   object
#  16  extraction         12043 non-null  object
#  17  amount             12043 non-null  float32
#  18  transaction_id     12043 non-null  object
#  19  country            12043 non-null  object
#  20  customer_id        12043 non-null  object
#  21  merchant_long_lat  7717 non-null   object
#  22  movement           12043 non-null  object
# dtypes: datetime64[ns](1), float32(4), int8(1), object(17)
# memory usage: 1.8+ MB

# %%
# The extraction column is in datetime format but is an object datatype
# Changing the date type
df['extraction'] = df['extraction'].apply(pd.to_datetime)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12043 entries, 0 to 12042
# Data columns (total 23 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   status             12043 non-null  object
#  1   card_present_flag  7717 non-null   float32
#  2   bpay_biller_code   885 non-null    object
#  3   account            12043 non-null  object
#  4   currency           12043 non-null  object
#  5   long_lat           12043 non-null  object
#  6   txn_description    12043 non-null  object
#  7   merchant_id        7717 non-null   object
#  8   merchant_code      883 non-null    float32
#  9   first_name         12043 non-null  object
#  10  balance            12043 non-null  float32
#  11  date               12043 non-null  datetime64[ns]
#  12  gender             12043 non-null  object
#  13  age                12043 non-null  int8
#  14  merchant_suburb    7717 non-null   object
#  15  merchant_state     7717 non-null   object
#  16  extraction         12043 non-null  datetime64[ns, UTC]
#  17  amount             12043 non-null  float32
#  18  transaction_id     12043 non-null  object
#  19  country            12043 non-null  object
#  20  customer_id        12043 non-null  object
#  21  merchant_long_lat  7717 non-null   object
#  22  movement           12043 non-null  object
# dtypes: datetime64[ns, UTC](1), datetime64[ns](1), float32(4), int8(1), object(16)
# memory usage: 1.8+ MB

# %%
# dropping the timezone
df['extraction'] = pd.to_datetime(df.extraction).dt.tz_localize(None)

# %%
df.head()
# Out:
#        status  card_present_flag bpay_biller_code         account currency  \
# 0  authorized                1.0              NaN  ACC-1598451071      AUD
# 1  authorized                0.0              NaN  ACC-1598451071      AUD
# 2  authorized                1.0              NaN  ACC-1222300524      AUD
# 3  authorized                1.0              NaN  ACC-1037050564      AUD
# 4  authorized                1.0              NaN  ACC-1598451071      AUD
#
#         long_lat txn_description                           merchant_id  \
# 0  153.41 -27.95             POS  81c48296-73be-44a7-befa-d053f48ce7cd
# 1  153.41 -27.95       SALES-POS  830a451c-316e-4a6a-bf25-e37caedca49e
# 2  151.23 -33.94             POS  835c231d-8cdf-4e96-859d-e9d571760cf0
# 3  153.10 -27.66       SALES-POS  48514682-c78a-4a88-b0da-2d6302e64673
# 4  153.41 -27.95       SALES-POS  b4e02c10-0852-4273-b8fd-7b3395e32eb0
#
#    merchant_code first_name  ...  age merchant_suburb merchant_state  \
# 0            NaN      Diana  ...   26         Ashmore            QLD
# 1            NaN      Diana  ...   26          Sydney            NSW
# 2            NaN    Michael  ...   38          Sydney            NSW
# 3            NaN     Rhonda  ...   40         Buderim            QLD
# 4            NaN      Diana  ...   26   Mermaid Beach            QLD
#
#            extraction     amount                    transaction_id    country  \
# 0 2018-08-01 01:01:15  16.250000  a623070bfead4541a6b0fff8a09e706c  Australia
# 1 2018-08-01 01:13:45  14.190000  13270a2a902145da9db4c951e04b51b9  Australia
# 2 2018-08-01 01:26:15   6.420000  feb79e7ecd7048a5a36ec889d1a94270  Australia
# 3 2018-08-01 01:38:45  40.900002  2698170da3704fd981b15e64a006079e  Australia
# 4 2018-08-01 01:51:15   3.250000  329adf79878c4cf0aeb4188b4691c266  Australia
#
#       customer_id merchant_long_lat movement
# 0  CUS-2487424745     153.38 -27.99    debit
# 1  CUS-2487424745     151.21 -33.87    debit
# 2  CUS-2142601169     151.21 -33.87    debit
# 3  CUS-1614226872     153.05 -26.68    debit
# 4  CUS-2487424745     153.44 -28.06    debit
#
# [5 rows x 23 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12043 entries, 0 to 12042
# Data columns (total 23 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   status             12043 non-null  object
#  1   card_present_flag  7717 non-null   float32
#  2   bpay_biller_code   885 non-null    object
#  3   account            12043 non-null  object
#  4   currency           12043 non-null  object
#  5   long_lat           12043 non-null  object
#  6   txn_description    12043 non-null  object
#  7   merchant_id        7717 non-null   object
#  8   merchant_code      883 non-null    float32
#  9   first_name         12043 non-null  object
#  10  balance            12043 non-null  float32
#  11  date               12043 non-null  datetime64[ns]
#  12  gender             12043 non-null  object
#  13  age                12043 non-null  int8
#  14  merchant_suburb    7717 non-null   object
#  15  merchant_state     7717 non-null   object
#  16  extraction         12043 non-null  datetime64[ns]
#  17  amount             12043 non-null  float32
#  18  transaction_id     12043 non-null  object
#  19  country            12043 non-null  object
#  20  customer_id        12043 non-null  object
#  21  merchant_long_lat  7717 non-null   object
#  22  movement           12043 non-null  object
# dtypes: datetime64[ns](2), float32(4), int8(1), object(16)
# memory usage: 1.8+ MB

# %% [markdown]
# #### Looking at the dataframe as is, there are at least 2 columns that appear to be NaN values, 'bpay_biller_code' and 'merchant_code'.

# %%
# Expanding all columns to check for other possible NaN columns
pd.set_option('max_columns', None)
pd.set_option('min_rows',25)
df
# Out:
#            status  card_present_flag bpay_biller_code         account  \
# 0      authorized                1.0              NaN  ACC-1598451071
# 1      authorized                0.0              NaN  ACC-1598451071
# 2      authorized                1.0              NaN  ACC-1222300524
# 3      authorized                1.0              NaN  ACC-1037050564
# 4      authorized                1.0              NaN  ACC-1598451071
# 5          posted                NaN              NaN  ACC-1608363396
# 6      authorized                1.0              NaN  ACC-2776252858
# 7      authorized                1.0              NaN  ACC-2776252858
# 8      authorized                1.0              NaN   ACC-182446574
# 9          posted                NaN              NaN   ACC-602667573
# 10         posted                NaN              NaN  ACC-2171593283
# 11         posted                NaN              NaN  ACC-2776252858
# ...           ...                ...              ...             ...
# 12031  authorized                0.0              NaN  ACC-1443681913
# 12032      posted                NaN              NaN  ACC-1710017148
# 12033  authorized                1.0              NaN  ACC-3100725361
# 12034  authorized                1.0              NaN  ACC-1516130869
# 12035      posted                NaN              NaN  ACC-1973887809
# 12036      posted                NaN              NaN  ACC-1349834573
# 12037      posted                NaN              NaN   ACC-240804743
# 12038  authorized                0.0              NaN  ACC-3021093232
# 12039  authorized                1.0              NaN  ACC-1608363396
# 12040  authorized                1.0              NaN  ACC-3827517394
# 12041  authorized                1.0              NaN  ACC-2920611728
# 12042  authorized                1.0              NaN  ACC-1443681913
#
#       currency       long_lat txn_description  \
# 0          AUD  153.41 -27.95             POS
# 1          AUD  153.41 -27.95       SALES-POS
# 2          AUD  151.23 -33.94             POS
# 3          AUD  153.10 -27.66       SALES-POS
# 4          AUD  153.41 -27.95       SALES-POS
# 5          AUD  151.22 -33.87         PAYMENT
# 6          AUD  144.95 -37.76       SALES-POS
# 7          AUD  144.95 -37.76             POS
# 8          AUD  116.06 -32.00             POS
# 9          AUD  151.23 -33.96      INTER BANK
# 10         AUD  146.94 -36.04         PAYMENT
# 11         AUD  144.95 -37.76         PAYMENT
# ...        ...            ...             ...
# 12031      AUD  150.92 -33.77       SALES-POS
# 12032      AUD  150.82 -34.01         PAYMENT
# 12033      AUD  145.73 -17.03       SALES-POS
# 12034      AUD  130.84 -12.45             POS
# 12035      AUD  115.78 -31.90         PAYMENT
# 12036      AUD  145.17 -37.84         PAYMENT
# 12037      AUD  121.48 -30.75         PAYMENT
# 12038      AUD  149.83 -29.47             POS
# 12039      AUD  151.22 -33.87       SALES-POS
# 12040      AUD  151.12 -33.89             POS
# 12041      AUD  144.96 -37.76       SALES-POS
# 12042      AUD  150.92 -33.77       SALES-POS
#
#                                 merchant_id  merchant_code first_name  \
# 0      81c48296-73be-44a7-befa-d053f48ce7cd            NaN      Diana
# 1      830a451c-316e-4a6a-bf25-e37caedca49e            NaN      Diana
# 2      835c231d-8cdf-4e96-859d-e9d571760cf0            NaN    Michael
# 3      48514682-c78a-4a88-b0da-2d6302e64673            NaN     Rhonda
# 4      b4e02c10-0852-4273-b8fd-7b3395e32eb0            NaN      Diana
# 5                                       NaN            NaN     Robert
# 6      3aa18033-a0a9-4190-a117-b7caaf4d07e3            NaN    Kristin
# 7      ee58145d-26e8-4b01-9cd9-62378014f21d            NaN    Kristin
# 8      cfbf535e-caa8-499f-9d41-bbdc2b836d85            NaN      Tonya
# 9                                       NaN            NaN    Michael
# 10                                      NaN            NaN   Fernando
# 11                                      NaN            NaN    Kristin
# ...                                     ...            ...        ...
# 12031  6fcdc956-3548-40b2-a2ce-9dbc6cb64eb9            NaN       Ryan
# 12032                                   NaN            NaN   Michelle
# 12033  f17a5cbd-fa5d-47db-8235-c7f449597dd0            NaN     Ronald
# 12034  7a3610ce-2f3c-4c7f-becf-987ddeb1c533            NaN    Jessica
# 12035                                   NaN            NaN    Antonio
# 12036                                   NaN            NaN    Matthew
# 12037                                   NaN            NaN    Kenneth
# 12038  32aa73dc-b7c2-4161-b14d-6271b96ce792            NaN    Melissa
# 12039  296a0500-8552-48ac-ac81-ec37065b568e            NaN     Robert
# 12040  e5975ab4-08f7-4725-a369-24cc0e35ed6e            NaN      Craig
# 12041  af49051a-591d-4b08-bd3c-27730b70ed37            NaN      Tyler
# 12042  f31f4b14-2040-40ec-a120-b141bb274cbd            NaN       Ryan
#
#             balance       date gender  age merchant_suburb merchant_state  \
# 0         35.389999 2018-08-01      F   26         Ashmore            QLD
# 1         21.200001 2018-08-01      F   26          Sydney            NSW
# 2          5.710000 2018-08-01      M   38          Sydney            NSW
# 3       2117.219971 2018-08-01      F   40         Buderim            QLD
# 4         17.950001 2018-08-01      F   26   Mermaid Beach            QLD
# 5       1705.430054 2018-08-01      M   20             NaN            NaN
# 6       1248.359985 2018-08-01      F   43        Kalkallo            VIC
# 7       1232.750000 2018-08-01      F   43       Melbourne            VIC
# 8        213.160004 2018-08-01      F   27          Yokine             WA
# 9        466.579987 2018-08-01      M   40             NaN            NaN
# 10      4348.500000 2018-08-01      M   19             NaN            NaN
# 11      1203.750000 2018-08-01      F   43             NaN            NaN
# ...             ...        ...    ...  ...             ...            ...
# 12031   5540.270020 2018-10-31      M   31    Marrickville            NSW
# 12032  20699.900391 2018-10-31      F   19             NaN            NaN
# 12033  10445.389648 2018-10-31      M   25      Smithfield            QLD
# 12034   4946.620117 2018-10-31      F   21     Darwin City             NT
# 12035   9349.509766 2018-10-31      M   26             NaN            NaN
# 12036  18127.500000 2018-10-31      M   39             NaN            NaN
# 12037  24775.660156 2018-10-31      M   29             NaN            NaN
# 12038  14054.139648 2018-10-31      F   30        Ringwood            VIC
# 12039   9137.790039 2018-10-31      M   20          Casula            NSW
# 12040  45394.570312 2018-10-31      M   28      Kings Park            NSW
# 12041  11350.669922 2018-10-31      M   69        Oakleigh            VIC
# 12042   5517.910156 2018-10-31      M   31          Mascot            NSW
#
#                extraction      amount                    transaction_id  \
# 0     2018-08-01 01:01:15   16.250000  a623070bfead4541a6b0fff8a09e706c
# 1     2018-08-01 01:13:45   14.190000  13270a2a902145da9db4c951e04b51b9
# 2     2018-08-01 01:26:15    6.420000  feb79e7ecd7048a5a36ec889d1a94270
# 3     2018-08-01 01:38:45   40.900002  2698170da3704fd981b15e64a006079e
# 4     2018-08-01 01:51:15    3.250000  329adf79878c4cf0aeb4188b4691c266
# 5     2018-08-01 02:00:00  163.000000  1005b48a6eda4ffd85e9b649dc9467d3
# 6     2018-08-01 02:23:04   61.060001  b79ca208099c4c28aa5dae966096d842
# 7     2018-08-01 04:11:25   15.610000  e1c4a50d6a0549cbb3710a62a2fa00d5
# 8     2018-08-01 04:40:00   19.250000  799e39eb2c1b411185424b0f2cd18bda
# 9     2018-08-01 06:00:00   21.000000  798a77869014441b840a7a8a23408332
# 10    2018-08-01 06:00:00   27.000000  baff17b27b2643c48c84fca7129e9611
# 11    2018-08-01 06:00:00   29.000000  78a1b6c3a5534d48828d8ed266ba9c2e
# ...                   ...         ...                               ...
# 12031 2018-10-31 21:56:11   70.510002  f82ed841f0404363b4a3782ce6118294
# 12032 2018-10-31 22:00:00   33.000000  96fe9c5dcda24b599e81b6f6d5bdcb66
# 12033 2018-10-31 22:22:21   26.590000  593930fd0e1640398b5638f74b7dee14
# 12034 2018-10-31 22:51:45   23.480000  74b737841b9548b494af32ba71627716
# 12035 2018-10-31 23:00:00   29.000000  dda53e538c5b4d5aae2481be22e60440
# 12036 2018-10-31 23:00:00   32.000000  df15d6f039554dcbb3ca02631ce22068
# 12037 2018-10-31 23:00:00   39.000000  c7bc398b9eb04e73933dc6d5a7beae0b
# 12038 2018-10-31 23:09:06    9.790000  f2e3e695c2ee4c50a4c8747f852cbe2e
# 12039 2018-10-31 23:21:46   63.869999  56e147e5485f4683b9076fcaaed76640
# 12040 2018-10-31 23:34:25   43.959999  2fdd4681827343f6af2e6519644a684a
# 12041 2018-10-31 23:47:05   30.770000  74aa9cd7e4af4c6d9cd7dbd28e9aedc9
# 12042 2018-10-31 23:59:44   22.360001  6d5218e04e8040b9996850ce11a19426
#
#          country     customer_id merchant_long_lat movement
# 0      Australia  CUS-2487424745     153.38 -27.99    debit
# 1      Australia  CUS-2487424745     151.21 -33.87    debit
# 2      Australia  CUS-2142601169     151.21 -33.87    debit
# 3      Australia  CUS-1614226872     153.05 -26.68    debit
# 4      Australia  CUS-2487424745     153.44 -28.06    debit
# 5      Australia  CUS-2688605418               NaN    debit
# 6      Australia  CUS-4123612273     144.95 -37.53    debit
# 7      Australia  CUS-4123612273     144.96 -37.81    debit
# 8      Australia  CUS-3026014945      115.85 -31.9    debit
# 9      Australia  CUS-2031327464               NaN    debit
# 10     Australia  CUS-2317998716               NaN    debit
# 11     Australia  CUS-4123612273               NaN    debit
# ...          ...             ...               ...      ...
# 12031  Australia  CUS-3129499595     151.17 -33.91    debit
# 12032  Australia   CUS-883482547               NaN    debit
# 12033  Australia  CUS-2178051368     145.69 -16.84    debit
# 12034  Australia   CUS-325142416     130.84 -12.46    debit
# 12035  Australia  CUS-1646621553               NaN    debit
# 12036  Australia  CUS-1790886359               NaN    debit
# 12037  Australia   CUS-261674136               NaN    debit
# 12038  Australia    CUS-55310383     145.23 -37.81    debit
# 12039  Australia  CUS-2688605418     150.88 -33.96    debit
# 12040  Australia  CUS-2663907001     150.92 -33.74    debit
# 12041  Australia  CUS-1388323263     145.09 -37.91    debit
# 12042  Australia  CUS-3129499595     151.19 -33.93    debit
#
# [12043 rows x 23 columns]

# %% [markdown]
# There appear no other immediate only NaN value colums

# %%
# some information on the dtype, column and row totals
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12043 entries, 0 to 12042
# Data columns (total 23 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   status             12043 non-null  object
#  1   card_present_flag  7717 non-null   float32
#  2   bpay_biller_code   885 non-null    object
#  3   account            12043 non-null  object
#  4   currency           12043 non-null  object
#  5   long_lat           12043 non-null  object
#  6   txn_description    12043 non-null  object
#  7   merchant_id        7717 non-null   object
#  8   merchant_code      883 non-null    float32
#  9   first_name         12043 non-null  object
#  10  balance            12043 non-null  float32
#  11  date               12043 non-null  datetime64[ns]
#  12  gender             12043 non-null  object
#  13  age                12043 non-null  int8
#  14  merchant_suburb    7717 non-null   object
#  15  merchant_state     7717 non-null   object
#  16  extraction         12043 non-null  datetime64[ns]
#  17  amount             12043 non-null  float32
#  18  transaction_id     12043 non-null  object
#  19  country            12043 non-null  object
#  20  customer_id        12043 non-null  object
#  21  merchant_long_lat  7717 non-null   object
#  22  movement           12043 non-null  object
# dtypes: datetime64[ns](2), float32(4), int8(1), object(16)
# memory usage: 1.8+ MB

# %%
# checking for total null values in all of the rows
df.isnull().sum()
# Out:
# status                   0
# card_present_flag     4326
# bpay_biller_code     11158
# account                  0
# currency                 0
# long_lat                 0
# txn_description          0
# merchant_id           4326
# merchant_code        11160
# first_name               0
# balance                  0
# date                     0
# gender                   0
# age                      0
# merchant_suburb       4326
# merchant_state        4326
# extraction               0
# amount                   0
# transaction_id           0
# country                  0
# customer_id              0
# merchant_long_lat     4326
# movement                 0
# dtype: int64

# %% [markdown]
# From this information we can notice that two rows are almost entirely null values. out of 12042 rows, 'bpay_biller_code' has 11158 null values and 'merchant_code' has 11160 null values. Both of these rows have nearly 90% missing data. From this we can conclude that these two rows can be dropped.
#
# 4 other rows have exactly the same amount of null values and we can explore this a bit further.

# %%
# dropping both rows and creating a new dataframe
df1 = df.drop(['bpay_biller_code', 'merchant_code'], axis = 1)
df1
# Out:
#            status  card_present_flag         account currency       long_lat  \
# 0      authorized                1.0  ACC-1598451071      AUD  153.41 -27.95
# 1      authorized                0.0  ACC-1598451071      AUD  153.41 -27.95
# 2      authorized                1.0  ACC-1222300524      AUD  151.23 -33.94
# 3      authorized                1.0  ACC-1037050564      AUD  153.10 -27.66
# 4      authorized                1.0  ACC-1598451071      AUD  153.41 -27.95
# 5          posted                NaN  ACC-1608363396      AUD  151.22 -33.87
# 6      authorized                1.0  ACC-2776252858      AUD  144.95 -37.76
# 7      authorized                1.0  ACC-2776252858      AUD  144.95 -37.76
# 8      authorized                1.0   ACC-182446574      AUD  116.06 -32.00
# 9          posted                NaN   ACC-602667573      AUD  151.23 -33.96
# 10         posted                NaN  ACC-2171593283      AUD  146.94 -36.04
# 11         posted                NaN  ACC-2776252858      AUD  144.95 -37.76
# ...           ...                ...             ...      ...            ...
# 12031  authorized                0.0  ACC-1443681913      AUD  150.92 -33.77
# 12032      posted                NaN  ACC-1710017148      AUD  150.82 -34.01
# 12033  authorized                1.0  ACC-3100725361      AUD  145.73 -17.03
# 12034  authorized                1.0  ACC-1516130869      AUD  130.84 -12.45
# 12035      posted                NaN  ACC-1973887809      AUD  115.78 -31.90
# 12036      posted                NaN  ACC-1349834573      AUD  145.17 -37.84
# 12037      posted                NaN   ACC-240804743      AUD  121.48 -30.75
# 12038  authorized                0.0  ACC-3021093232      AUD  149.83 -29.47
# 12039  authorized                1.0  ACC-1608363396      AUD  151.22 -33.87
# 12040  authorized                1.0  ACC-3827517394      AUD  151.12 -33.89
# 12041  authorized                1.0  ACC-2920611728      AUD  144.96 -37.76
# 12042  authorized                1.0  ACC-1443681913      AUD  150.92 -33.77
#
#       txn_description                           merchant_id first_name  \
# 0                 POS  81c48296-73be-44a7-befa-d053f48ce7cd      Diana
# 1           SALES-POS  830a451c-316e-4a6a-bf25-e37caedca49e      Diana
# 2                 POS  835c231d-8cdf-4e96-859d-e9d571760cf0    Michael
# 3           SALES-POS  48514682-c78a-4a88-b0da-2d6302e64673     Rhonda
# 4           SALES-POS  b4e02c10-0852-4273-b8fd-7b3395e32eb0      Diana
# 5             PAYMENT                                   NaN     Robert
# 6           SALES-POS  3aa18033-a0a9-4190-a117-b7caaf4d07e3    Kristin
# 7                 POS  ee58145d-26e8-4b01-9cd9-62378014f21d    Kristin
# 8                 POS  cfbf535e-caa8-499f-9d41-bbdc2b836d85      Tonya
# 9          INTER BANK                                   NaN    Michael
# 10            PAYMENT                                   NaN   Fernando
# 11            PAYMENT                                   NaN    Kristin
# ...               ...                                   ...        ...
# 12031       SALES-POS  6fcdc956-3548-40b2-a2ce-9dbc6cb64eb9       Ryan
# 12032         PAYMENT                                   NaN   Michelle
# 12033       SALES-POS  f17a5cbd-fa5d-47db-8235-c7f449597dd0     Ronald
# 12034             POS  7a3610ce-2f3c-4c7f-becf-987ddeb1c533    Jessica
# 12035         PAYMENT                                   NaN    Antonio
# 12036         PAYMENT                                   NaN    Matthew
# 12037         PAYMENT                                   NaN    Kenneth
# 12038             POS  32aa73dc-b7c2-4161-b14d-6271b96ce792    Melissa
# 12039       SALES-POS  296a0500-8552-48ac-ac81-ec37065b568e     Robert
# 12040             POS  e5975ab4-08f7-4725-a369-24cc0e35ed6e      Craig
# 12041       SALES-POS  af49051a-591d-4b08-bd3c-27730b70ed37      Tyler
# 12042       SALES-POS  f31f4b14-2040-40ec-a120-b141bb274cbd       Ryan
#
#             balance       date gender  age merchant_suburb merchant_state  \
# 0         35.389999 2018-08-01      F   26         Ashmore            QLD
# 1         21.200001 2018-08-01      F   26          Sydney            NSW
# 2          5.710000 2018-08-01      M   38          Sydney            NSW
# 3       2117.219971 2018-08-01      F   40         Buderim            QLD
# 4         17.950001 2018-08-01      F   26   Mermaid Beach            QLD
# 5       1705.430054 2018-08-01      M   20             NaN            NaN
# 6       1248.359985 2018-08-01      F   43        Kalkallo            VIC
# 7       1232.750000 2018-08-01      F   43       Melbourne            VIC
# 8        213.160004 2018-08-01      F   27          Yokine             WA
# 9        466.579987 2018-08-01      M   40             NaN            NaN
# 10      4348.500000 2018-08-01      M   19             NaN            NaN
# 11      1203.750000 2018-08-01      F   43             NaN            NaN
# ...             ...        ...    ...  ...             ...            ...
# 12031   5540.270020 2018-10-31      M   31    Marrickville            NSW
# 12032  20699.900391 2018-10-31      F   19             NaN            NaN
# 12033  10445.389648 2018-10-31      M   25      Smithfield            QLD
# 12034   4946.620117 2018-10-31      F   21     Darwin City             NT
# 12035   9349.509766 2018-10-31      M   26             NaN            NaN
# 12036  18127.500000 2018-10-31      M   39             NaN            NaN
# 12037  24775.660156 2018-10-31      M   29             NaN            NaN
# 12038  14054.139648 2018-10-31      F   30        Ringwood            VIC
# 12039   9137.790039 2018-10-31      M   20          Casula            NSW
# 12040  45394.570312 2018-10-31      M   28      Kings Park            NSW
# 12041  11350.669922 2018-10-31      M   69        Oakleigh            VIC
# 12042   5517.910156 2018-10-31      M   31          Mascot            NSW
#
#                extraction      amount                    transaction_id  \
# 0     2018-08-01 01:01:15   16.250000  a623070bfead4541a6b0fff8a09e706c
# 1     2018-08-01 01:13:45   14.190000  13270a2a902145da9db4c951e04b51b9
# 2     2018-08-01 01:26:15    6.420000  feb79e7ecd7048a5a36ec889d1a94270
# 3     2018-08-01 01:38:45   40.900002  2698170da3704fd981b15e64a006079e
# 4     2018-08-01 01:51:15    3.250000  329adf79878c4cf0aeb4188b4691c266
# 5     2018-08-01 02:00:00  163.000000  1005b48a6eda4ffd85e9b649dc9467d3
# 6     2018-08-01 02:23:04   61.060001  b79ca208099c4c28aa5dae966096d842
# 7     2018-08-01 04:11:25   15.610000  e1c4a50d6a0549cbb3710a62a2fa00d5
# 8     2018-08-01 04:40:00   19.250000  799e39eb2c1b411185424b0f2cd18bda
# 9     2018-08-01 06:00:00   21.000000  798a77869014441b840a7a8a23408332
# 10    2018-08-01 06:00:00   27.000000  baff17b27b2643c48c84fca7129e9611
# 11    2018-08-01 06:00:00   29.000000  78a1b6c3a5534d48828d8ed266ba9c2e
# ...                   ...         ...                               ...
# 12031 2018-10-31 21:56:11   70.510002  f82ed841f0404363b4a3782ce6118294
# 12032 2018-10-31 22:00:00   33.000000  96fe9c5dcda24b599e81b6f6d5bdcb66
# 12033 2018-10-31 22:22:21   26.590000  593930fd0e1640398b5638f74b7dee14
# 12034 2018-10-31 22:51:45   23.480000  74b737841b9548b494af32ba71627716
# 12035 2018-10-31 23:00:00   29.000000  dda53e538c5b4d5aae2481be22e60440
# 12036 2018-10-31 23:00:00   32.000000  df15d6f039554dcbb3ca02631ce22068
# 12037 2018-10-31 23:00:00   39.000000  c7bc398b9eb04e73933dc6d5a7beae0b
# 12038 2018-10-31 23:09:06    9.790000  f2e3e695c2ee4c50a4c8747f852cbe2e
# 12039 2018-10-31 23:21:46   63.869999  56e147e5485f4683b9076fcaaed76640
# 12040 2018-10-31 23:34:25   43.959999  2fdd4681827343f6af2e6519644a684a
# 12041 2018-10-31 23:47:05   30.770000  74aa9cd7e4af4c6d9cd7dbd28e9aedc9
# 12042 2018-10-31 23:59:44   22.360001  6d5218e04e8040b9996850ce11a19426
#
#          country     customer_id merchant_long_lat movement
# 0      Australia  CUS-2487424745     153.38 -27.99    debit
# 1      Australia  CUS-2487424745     151.21 -33.87    debit
# 2      Australia  CUS-2142601169     151.21 -33.87    debit
# 3      Australia  CUS-1614226872     153.05 -26.68    debit
# 4      Australia  CUS-2487424745     153.44 -28.06    debit
# 5      Australia  CUS-2688605418               NaN    debit
# 6      Australia  CUS-4123612273     144.95 -37.53    debit
# 7      Australia  CUS-4123612273     144.96 -37.81    debit
# 8      Australia  CUS-3026014945      115.85 -31.9    debit
# 9      Australia  CUS-2031327464               NaN    debit
# 10     Australia  CUS-2317998716               NaN    debit
# 11     Australia  CUS-4123612273               NaN    debit
# ...          ...             ...               ...      ...
# 12031  Australia  CUS-3129499595     151.17 -33.91    debit
# 12032  Australia   CUS-883482547               NaN    debit
# 12033  Australia  CUS-2178051368     145.69 -16.84    debit
# 12034  Australia   CUS-325142416     130.84 -12.46    debit
# 12035  Australia  CUS-1646621553               NaN    debit
# 12036  Australia  CUS-1790886359               NaN    debit
# 12037  Australia   CUS-261674136               NaN    debit
# 12038  Australia    CUS-55310383     145.23 -37.81    debit
# 12039  Australia  CUS-2688605418     150.88 -33.96    debit
# 12040  Australia  CUS-2663907001     150.92 -33.74    debit
# 12041  Australia  CUS-1388323263     145.09 -37.91    debit
# 12042  Australia  CUS-3129499595     151.19 -33.93    debit
#
# [12043 rows x 21 columns]

# %%
# checking to see if any currency besides AUD was used
df1[df1['currency'] != 'AUD']
# Out:
# Empty DataFrame
# Columns: [status, card_present_flag, account, currency, long_lat, txn_description, merchant_id, first_name, balance, date, gender, age, merchant_suburb, merchant_state, extraction, amount, transaction_id, country, customer_id, merchant_long_lat, movement]
# Index: []

# %%
# checking if any purchases were made outside of Australia
df1[df1['country'] != 'Australia']
# Out:
# Empty DataFrame
# Columns: [status, card_present_flag, account, currency, long_lat, txn_description, merchant_id, first_name, balance, date, gender, age, merchant_suburb, merchant_state, extraction, amount, transaction_id, country, customer_id, merchant_long_lat, movement]
# Index: []

# %% [markdown]
# Both of in these searches yielded 0 results which means that all the values in both of the checked columuns are the same. We know that all currency is in AUD and all transactions were made within Australia. These two columns provide no further insight and they can be dropped

# %%
# Dropping currency and country columns
df1.drop(['country','currency'], axis = 1, inplace = True)

# %%
# Check the resulting dataframe
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12043 entries, 0 to 12042
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   status             12043 non-null  object
#  1   card_present_flag  7717 non-null   float32
#  2   account            12043 non-null  object
#  3   long_lat           12043 non-null  object
#  4   txn_description    12043 non-null  object
#  5   merchant_id        7717 non-null   object
#  6   first_name         12043 non-null  object
#  7   balance            12043 non-null  float32
#  8   date               12043 non-null  datetime64[ns]
#  9   gender             12043 non-null  object
#  10  age                12043 non-null  int8
#  11  merchant_suburb    7717 non-null   object
#  12  merchant_state     7717 non-null   object
#  13  extraction         12043 non-null  datetime64[ns]
#  14  amount             12043 non-null  float32
#  15  transaction_id     12043 non-null  object
#  16  customer_id        12043 non-null  object
#  17  merchant_long_lat  7717 non-null   object
#  18  movement           12043 non-null  object
# dtypes: datetime64[ns](2), float32(3), int8(1), object(13)
# memory usage: 1.5+ MB

# %%
df1.head()
# Out:
#        status  card_present_flag         account       long_lat  \
# 0  authorized                1.0  ACC-1598451071  153.41 -27.95
# 1  authorized                0.0  ACC-1598451071  153.41 -27.95
# 2  authorized                1.0  ACC-1222300524  151.23 -33.94
# 3  authorized                1.0  ACC-1037050564  153.10 -27.66
# 4  authorized                1.0  ACC-1598451071  153.41 -27.95
#
#   txn_description                           merchant_id first_name  \
# 0             POS  81c48296-73be-44a7-befa-d053f48ce7cd      Diana
# 1       SALES-POS  830a451c-316e-4a6a-bf25-e37caedca49e      Diana
# 2             POS  835c231d-8cdf-4e96-859d-e9d571760cf0    Michael
# 3       SALES-POS  48514682-c78a-4a88-b0da-2d6302e64673     Rhonda
# 4       SALES-POS  b4e02c10-0852-4273-b8fd-7b3395e32eb0      Diana
#
#        balance       date gender  age merchant_suburb merchant_state  \
# 0    35.389999 2018-08-01      F   26         Ashmore            QLD
# 1    21.200001 2018-08-01      F   26          Sydney            NSW
# 2     5.710000 2018-08-01      M   38          Sydney            NSW
# 3  2117.219971 2018-08-01      F   40         Buderim            QLD
# 4    17.950001 2018-08-01      F   26   Mermaid Beach            QLD
#
#            extraction     amount                    transaction_id  \
# 0 2018-08-01 01:01:15  16.250000  a623070bfead4541a6b0fff8a09e706c
# 1 2018-08-01 01:13:45  14.190000  13270a2a902145da9db4c951e04b51b9
# 2 2018-08-01 01:26:15   6.420000  feb79e7ecd7048a5a36ec889d1a94270
# 3 2018-08-01 01:38:45  40.900002  2698170da3704fd981b15e64a006079e
# 4 2018-08-01 01:51:15   3.250000  329adf79878c4cf0aeb4188b4691c266
#
#       customer_id merchant_long_lat movement
# 0  CUS-2487424745     153.38 -27.99    debit
# 1  CUS-2487424745     151.21 -33.87    debit
# 2  CUS-2142601169     151.21 -33.87    debit
# 3  CUS-1614226872     153.05 -26.68    debit
# 4  CUS-2487424745     153.44 -28.06    debit

# %%
# The transaction_id column seems to be a randomly generated value consisting of letters and numbers. 
# I will check for duplicates to make sure this is the case

dupes = df1.duplicated(subset = 'transaction_id').sum()
dupes

#df.describe(exclude = [np.number], datetime_is_numeric=True).loc[['unique','top' ,'freq']]
# Out:
# 0

# %% [markdown]
# There are no matching values in the transaction_id column. This  indicates that the values are all different for each transaction regardles of whether the same customer is making another purchase. So I will drop this column as it will not give us any information.

# %%
# dropping the transaction_id column
df1.drop('transaction_id', axis = 1, inplace = True)
df1.head()
# Out:
#        status  card_present_flag         account       long_lat  \
# 0  authorized                1.0  ACC-1598451071  153.41 -27.95
# 1  authorized                0.0  ACC-1598451071  153.41 -27.95
# 2  authorized                1.0  ACC-1222300524  151.23 -33.94
# 3  authorized                1.0  ACC-1037050564  153.10 -27.66
# 4  authorized                1.0  ACC-1598451071  153.41 -27.95
#
#   txn_description                           merchant_id first_name  \
# 0             POS  81c48296-73be-44a7-befa-d053f48ce7cd      Diana
# 1       SALES-POS  830a451c-316e-4a6a-bf25-e37caedca49e      Diana
# 2             POS  835c231d-8cdf-4e96-859d-e9d571760cf0    Michael
# 3       SALES-POS  48514682-c78a-4a88-b0da-2d6302e64673     Rhonda
# 4       SALES-POS  b4e02c10-0852-4273-b8fd-7b3395e32eb0      Diana
#
#        balance       date gender  age merchant_suburb merchant_state  \
# 0    35.389999 2018-08-01      F   26         Ashmore            QLD
# 1    21.200001 2018-08-01      F   26          Sydney            NSW
# 2     5.710000 2018-08-01      M   38          Sydney            NSW
# 3  2117.219971 2018-08-01      F   40         Buderim            QLD
# 4    17.950001 2018-08-01      F   26   Mermaid Beach            QLD
#
#            extraction     amount     customer_id merchant_long_lat movement
# 0 2018-08-01 01:01:15  16.250000  CUS-2487424745     153.38 -27.99    debit
# 1 2018-08-01 01:13:45  14.190000  CUS-2487424745     151.21 -33.87    debit
# 2 2018-08-01 01:26:15   6.420000  CUS-2142601169     151.21 -33.87    debit
# 3 2018-08-01 01:38:45  40.900002  CUS-1614226872     153.05 -26.68    debit
# 4 2018-08-01 01:51:15   3.250000  CUS-2487424745     153.44 -28.06    debit

# %%
# Privacy is important. It appears that the customer_id, first_name and account are all linked 
# Therefore I will drop the name and the account column as we can use the customer_id for analysis 

# first I will group by first_name to check
df1.groupby(['first_name'])['account', 'customer_id'].count()
# Out:
# <ipython-input-23-8349221b96a4>:5: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df1.groupby(['first_name'])['account', 'customer_id'].count()
#             account  customer_id
# first_name
# Abigail         102          102
# Alexander        91           91
# Amy             124          124
# Andrew           34           34
# Antonio         115          115
# Ashley           75           75
# Barry           122          122
# Billy            77           77
# Brian            63           63
# Catherine        62           62
# Charles         145          145
# Christine       139          139
# ...             ...          ...
# Ryan            239          239
# Sandra          174          174
# Sarah            86           86
# Scott           109          109
# Stephanie        73           73
# Susan           282          282
# Tiffany         230          230
# Tim              78           78
# Timothy          72           72
# Tonya           292          292
# Tyler           218          218
# Virginia        199          199
#
# [80 rows x 2 columns]

# %% [markdown]
# As hypothesized, each customer has an account and customer_id linked to their name.

# %%
# dropping the account and first_name columns for privacy purposes
df1.drop(['account', 'first_name'], axis = 1, inplace = True)

# %%
df1.head()
# Out:
#        status  card_present_flag       long_lat txn_description  \
# 0  authorized                1.0  153.41 -27.95             POS
# 1  authorized                0.0  153.41 -27.95       SALES-POS
# 2  authorized                1.0  151.23 -33.94             POS
# 3  authorized                1.0  153.10 -27.66       SALES-POS
# 4  authorized                1.0  153.41 -27.95       SALES-POS
#
#                             merchant_id      balance       date gender  age  \
# 0  81c48296-73be-44a7-befa-d053f48ce7cd    35.389999 2018-08-01      F   26
# 1  830a451c-316e-4a6a-bf25-e37caedca49e    21.200001 2018-08-01      F   26
# 2  835c231d-8cdf-4e96-859d-e9d571760cf0     5.710000 2018-08-01      M   38
# 3  48514682-c78a-4a88-b0da-2d6302e64673  2117.219971 2018-08-01      F   40
# 4  b4e02c10-0852-4273-b8fd-7b3395e32eb0    17.950001 2018-08-01      F   26
#
#   merchant_suburb merchant_state          extraction     amount  \
# 0         Ashmore            QLD 2018-08-01 01:01:15  16.250000
# 1          Sydney            NSW 2018-08-01 01:13:45  14.190000
# 2          Sydney            NSW 2018-08-01 01:26:15   6.420000
# 3         Buderim            QLD 2018-08-01 01:38:45  40.900002
# 4   Mermaid Beach            QLD 2018-08-01 01:51:15   3.250000
#
#       customer_id merchant_long_lat movement
# 0  CUS-2487424745     153.38 -27.99    debit
# 1  CUS-2487424745     151.21 -33.87    debit
# 2  CUS-2142601169     151.21 -33.87    debit
# 3  CUS-1614226872     153.05 -26.68    debit
# 4  CUS-2487424745     153.44 -28.06    debit

# %% [markdown]
# ### Back to creating a data frame of the 4 rows with the same null values

# %%
equalnull_df = df1[['card_present_flag','merchant_id','merchant_suburb', 'merchant_state','merchant_long_lat' ]]

# %%
equalnull_df
# Out:
#        card_present_flag                           merchant_id  \
# 0                    1.0  81c48296-73be-44a7-befa-d053f48ce7cd
# 1                    0.0  830a451c-316e-4a6a-bf25-e37caedca49e
# 2                    1.0  835c231d-8cdf-4e96-859d-e9d571760cf0
# 3                    1.0  48514682-c78a-4a88-b0da-2d6302e64673
# 4                    1.0  b4e02c10-0852-4273-b8fd-7b3395e32eb0
# 5                    NaN                                   NaN
# 6                    1.0  3aa18033-a0a9-4190-a117-b7caaf4d07e3
# 7                    1.0  ee58145d-26e8-4b01-9cd9-62378014f21d
# 8                    1.0  cfbf535e-caa8-499f-9d41-bbdc2b836d85
# 9                    NaN                                   NaN
# 10                   NaN                                   NaN
# 11                   NaN                                   NaN
# ...                  ...                                   ...
# 12031                0.0  6fcdc956-3548-40b2-a2ce-9dbc6cb64eb9
# 12032                NaN                                   NaN
# 12033                1.0  f17a5cbd-fa5d-47db-8235-c7f449597dd0
# 12034                1.0  7a3610ce-2f3c-4c7f-becf-987ddeb1c533
# 12035                NaN                                   NaN
# 12036                NaN                                   NaN
# 12037                NaN                                   NaN
# 12038                0.0  32aa73dc-b7c2-4161-b14d-6271b96ce792
# 12039                1.0  296a0500-8552-48ac-ac81-ec37065b568e
# 12040                1.0  e5975ab4-08f7-4725-a369-24cc0e35ed6e
# 12041                1.0  af49051a-591d-4b08-bd3c-27730b70ed37
# 12042                1.0  f31f4b14-2040-40ec-a120-b141bb274cbd
#
#       merchant_suburb merchant_state merchant_long_lat
# 0             Ashmore            QLD     153.38 -27.99
# 1              Sydney            NSW     151.21 -33.87
# 2              Sydney            NSW     151.21 -33.87
# 3             Buderim            QLD     153.05 -26.68
# 4       Mermaid Beach            QLD     153.44 -28.06
# 5                 NaN            NaN               NaN
# 6            Kalkallo            VIC     144.95 -37.53
# 7           Melbourne            VIC     144.96 -37.81
# 8              Yokine             WA      115.85 -31.9
# 9                 NaN            NaN               NaN
# 10                NaN            NaN               NaN
# 11                NaN            NaN               NaN
# ...               ...            ...               ...
# 12031    Marrickville            NSW     151.17 -33.91
# 12032             NaN            NaN               NaN
# 12033      Smithfield            QLD     145.69 -16.84
# 12034     Darwin City             NT     130.84 -12.46
# 12035             NaN            NaN               NaN
# 12036             NaN            NaN               NaN
# 12037             NaN            NaN               NaN
# 12038        Ringwood            VIC     145.23 -37.81
# 12039          Casula            NSW     150.88 -33.96
# 12040      Kings Park            NSW     150.92 -33.74
# 12041        Oakleigh            VIC     145.09 -37.91
# 12042          Mascot            NSW     151.19 -33.93
#
# [12043 rows x 5 columns]

# %%
# changing the number of rows that appear, to look for insight as to why all 4 columns have the same amount of null values
pd.set_option('display.min_rows', 25)
equalnull_df
# Out:
#        card_present_flag                           merchant_id  \
# 0                    1.0  81c48296-73be-44a7-befa-d053f48ce7cd
# 1                    0.0  830a451c-316e-4a6a-bf25-e37caedca49e
# 2                    1.0  835c231d-8cdf-4e96-859d-e9d571760cf0
# 3                    1.0  48514682-c78a-4a88-b0da-2d6302e64673
# 4                    1.0  b4e02c10-0852-4273-b8fd-7b3395e32eb0
# 5                    NaN                                   NaN
# 6                    1.0  3aa18033-a0a9-4190-a117-b7caaf4d07e3
# 7                    1.0  ee58145d-26e8-4b01-9cd9-62378014f21d
# 8                    1.0  cfbf535e-caa8-499f-9d41-bbdc2b836d85
# 9                    NaN                                   NaN
# 10                   NaN                                   NaN
# 11                   NaN                                   NaN
# ...                  ...                                   ...
# 12031                0.0  6fcdc956-3548-40b2-a2ce-9dbc6cb64eb9
# 12032                NaN                                   NaN
# 12033                1.0  f17a5cbd-fa5d-47db-8235-c7f449597dd0
# 12034                1.0  7a3610ce-2f3c-4c7f-becf-987ddeb1c533
# 12035                NaN                                   NaN
# 12036                NaN                                   NaN
# 12037                NaN                                   NaN
# 12038                0.0  32aa73dc-b7c2-4161-b14d-6271b96ce792
# 12039                1.0  296a0500-8552-48ac-ac81-ec37065b568e
# 12040                1.0  e5975ab4-08f7-4725-a369-24cc0e35ed6e
# 12041                1.0  af49051a-591d-4b08-bd3c-27730b70ed37
# 12042                1.0  f31f4b14-2040-40ec-a120-b141bb274cbd
#
#       merchant_suburb merchant_state merchant_long_lat
# 0             Ashmore            QLD     153.38 -27.99
# 1              Sydney            NSW     151.21 -33.87
# 2              Sydney            NSW     151.21 -33.87
# 3             Buderim            QLD     153.05 -26.68
# 4       Mermaid Beach            QLD     153.44 -28.06
# 5                 NaN            NaN               NaN
# 6            Kalkallo            VIC     144.95 -37.53
# 7           Melbourne            VIC     144.96 -37.81
# 8              Yokine             WA      115.85 -31.9
# 9                 NaN            NaN               NaN
# 10                NaN            NaN               NaN
# 11                NaN            NaN               NaN
# ...               ...            ...               ...
# 12031    Marrickville            NSW     151.17 -33.91
# 12032             NaN            NaN               NaN
# 12033      Smithfield            QLD     145.69 -16.84
# 12034     Darwin City             NT     130.84 -12.46
# 12035             NaN            NaN               NaN
# 12036             NaN            NaN               NaN
# 12037             NaN            NaN               NaN
# 12038        Ringwood            VIC     145.23 -37.81
# 12039          Casula            NSW     150.88 -33.96
# 12040      Kings Park            NSW     150.92 -33.74
# 12041        Oakleigh            VIC     145.09 -37.91
# 12042          Mascot            NSW     151.19 -33.93
#
# [12043 rows x 5 columns]

# %% [markdown]
# Looking at this data, we can tell that all four columns have null values in the same rows.

# %% [markdown]
# --------

# %% [markdown]
# ### Returning to the original dataframe

# %%
df1
# Out:
#            status  card_present_flag       long_lat txn_description  \
# 0      authorized                1.0  153.41 -27.95             POS
# 1      authorized                0.0  153.41 -27.95       SALES-POS
# 2      authorized                1.0  151.23 -33.94             POS
# 3      authorized                1.0  153.10 -27.66       SALES-POS
# 4      authorized                1.0  153.41 -27.95       SALES-POS
# 5          posted                NaN  151.22 -33.87         PAYMENT
# 6      authorized                1.0  144.95 -37.76       SALES-POS
# 7      authorized                1.0  144.95 -37.76             POS
# 8      authorized                1.0  116.06 -32.00             POS
# 9          posted                NaN  151.23 -33.96      INTER BANK
# 10         posted                NaN  146.94 -36.04         PAYMENT
# 11         posted                NaN  144.95 -37.76         PAYMENT
# ...           ...                ...            ...             ...
# 12031  authorized                0.0  150.92 -33.77       SALES-POS
# 12032      posted                NaN  150.82 -34.01         PAYMENT
# 12033  authorized                1.0  145.73 -17.03       SALES-POS
# 12034  authorized                1.0  130.84 -12.45             POS
# 12035      posted                NaN  115.78 -31.90         PAYMENT
# 12036      posted                NaN  145.17 -37.84         PAYMENT
# 12037      posted                NaN  121.48 -30.75         PAYMENT
# 12038  authorized                0.0  149.83 -29.47             POS
# 12039  authorized                1.0  151.22 -33.87       SALES-POS
# 12040  authorized                1.0  151.12 -33.89             POS
# 12041  authorized                1.0  144.96 -37.76       SALES-POS
# 12042  authorized                1.0  150.92 -33.77       SALES-POS
#
#                                 merchant_id       balance       date gender  \
# 0      81c48296-73be-44a7-befa-d053f48ce7cd     35.389999 2018-08-01      F
# 1      830a451c-316e-4a6a-bf25-e37caedca49e     21.200001 2018-08-01      F
# 2      835c231d-8cdf-4e96-859d-e9d571760cf0      5.710000 2018-08-01      M
# 3      48514682-c78a-4a88-b0da-2d6302e64673   2117.219971 2018-08-01      F
# 4      b4e02c10-0852-4273-b8fd-7b3395e32eb0     17.950001 2018-08-01      F
# 5                                       NaN   1705.430054 2018-08-01      M
# 6      3aa18033-a0a9-4190-a117-b7caaf4d07e3   1248.359985 2018-08-01      F
# 7      ee58145d-26e8-4b01-9cd9-62378014f21d   1232.750000 2018-08-01      F
# 8      cfbf535e-caa8-499f-9d41-bbdc2b836d85    213.160004 2018-08-01      F
# 9                                       NaN    466.579987 2018-08-01      M
# 10                                      NaN   4348.500000 2018-08-01      M
# 11                                      NaN   1203.750000 2018-08-01      F
# ...                                     ...           ...        ...    ...
# 12031  6fcdc956-3548-40b2-a2ce-9dbc6cb64eb9   5540.270020 2018-10-31      M
# 12032                                   NaN  20699.900391 2018-10-31      F
# 12033  f17a5cbd-fa5d-47db-8235-c7f449597dd0  10445.389648 2018-10-31      M
# 12034  7a3610ce-2f3c-4c7f-becf-987ddeb1c533   4946.620117 2018-10-31      F
# 12035                                   NaN   9349.509766 2018-10-31      M
# 12036                                   NaN  18127.500000 2018-10-31      M
# 12037                                   NaN  24775.660156 2018-10-31      M
# 12038  32aa73dc-b7c2-4161-b14d-6271b96ce792  14054.139648 2018-10-31      F
# 12039  296a0500-8552-48ac-ac81-ec37065b568e   9137.790039 2018-10-31      M
# 12040  e5975ab4-08f7-4725-a369-24cc0e35ed6e  45394.570312 2018-10-31      M
# 12041  af49051a-591d-4b08-bd3c-27730b70ed37  11350.669922 2018-10-31      M
# 12042  f31f4b14-2040-40ec-a120-b141bb274cbd   5517.910156 2018-10-31      M
#
#        age merchant_suburb merchant_state          extraction      amount  \
# 0       26         Ashmore            QLD 2018-08-01 01:01:15   16.250000
# 1       26          Sydney            NSW 2018-08-01 01:13:45   14.190000
# 2       38          Sydney            NSW 2018-08-01 01:26:15    6.420000
# 3       40         Buderim            QLD 2018-08-01 01:38:45   40.900002
# 4       26   Mermaid Beach            QLD 2018-08-01 01:51:15    3.250000
# 5       20             NaN            NaN 2018-08-01 02:00:00  163.000000
# 6       43        Kalkallo            VIC 2018-08-01 02:23:04   61.060001
# 7       43       Melbourne            VIC 2018-08-01 04:11:25   15.610000
# 8       27          Yokine             WA 2018-08-01 04:40:00   19.250000
# 9       40             NaN            NaN 2018-08-01 06:00:00   21.000000
# 10      19             NaN            NaN 2018-08-01 06:00:00   27.000000
# 11      43             NaN            NaN 2018-08-01 06:00:00   29.000000
# ...    ...             ...            ...                 ...         ...
# 12031   31    Marrickville            NSW 2018-10-31 21:56:11   70.510002
# 12032   19             NaN            NaN 2018-10-31 22:00:00   33.000000
# 12033   25      Smithfield            QLD 2018-10-31 22:22:21   26.590000
# 12034   21     Darwin City             NT 2018-10-31 22:51:45   23.480000
# 12035   26             NaN            NaN 2018-10-31 23:00:00   29.000000
# 12036   39             NaN            NaN 2018-10-31 23:00:00   32.000000
# 12037   29             NaN            NaN 2018-10-31 23:00:00   39.000000
# 12038   30        Ringwood            VIC 2018-10-31 23:09:06    9.790000
# 12039   20          Casula            NSW 2018-10-31 23:21:46   63.869999
# 12040   28      Kings Park            NSW 2018-10-31 23:34:25   43.959999
# 12041   69        Oakleigh            VIC 2018-10-31 23:47:05   30.770000
# 12042   31          Mascot            NSW 2018-10-31 23:59:44   22.360001
#
#           customer_id merchant_long_lat movement
# 0      CUS-2487424745     153.38 -27.99    debit
# 1      CUS-2487424745     151.21 -33.87    debit
# 2      CUS-2142601169     151.21 -33.87    debit
# 3      CUS-1614226872     153.05 -26.68    debit
# 4      CUS-2487424745     153.44 -28.06    debit
# 5      CUS-2688605418               NaN    debit
# 6      CUS-4123612273     144.95 -37.53    debit
# 7      CUS-4123612273     144.96 -37.81    debit
# 8      CUS-3026014945      115.85 -31.9    debit
# 9      CUS-2031327464               NaN    debit
# 10     CUS-2317998716               NaN    debit
# 11     CUS-4123612273               NaN    debit
# ...               ...               ...      ...
# 12031  CUS-3129499595     151.17 -33.91    debit
# 12032   CUS-883482547               NaN    debit
# 12033  CUS-2178051368     145.69 -16.84    debit
# 12034   CUS-325142416     130.84 -12.46    debit
# 12035  CUS-1646621553               NaN    debit
# 12036  CUS-1790886359               NaN    debit
# 12037   CUS-261674136               NaN    debit
# 12038    CUS-55310383     145.23 -37.81    debit
# 12039  CUS-2688605418     150.88 -33.96    debit
# 12040  CUS-2663907001     150.92 -33.74    debit
# 12041  CUS-1388323263     145.09 -37.91    debit
# 12042  CUS-3129499595     151.19 -33.93    debit
#
# [12043 rows x 16 columns]

# %% [markdown]
# #

# %% [markdown]
# Looking a little closer it appears that in the status column values with status = posted also have the missing values of the equalnull_df we just looked at.

# %%
# checking to see if column status = posted has a card_present_value of NaN
pd.reset_option('display.min_rows')
df1[df1['status'] == 'posted']
# Out:
#        status  card_present_flag       long_lat txn_description merchant_id  \
# 5      posted                NaN  151.22 -33.87         PAYMENT         NaN
# 9      posted                NaN  151.23 -33.96      INTER BANK         NaN
# 10     posted                NaN  146.94 -36.04         PAYMENT         NaN
# 11     posted                NaN  144.95 -37.76         PAYMENT         NaN
# 13     posted                NaN  151.27 -33.76      INTER BANK         NaN
# ...       ...                ...            ...             ...         ...
# 12027  posted                NaN  144.71 -37.58      PHONE BANK         NaN
# 12032  posted                NaN  150.82 -34.01         PAYMENT         NaN
# 12035  posted                NaN  115.78 -31.90         PAYMENT         NaN
# 12036  posted                NaN  145.17 -37.84         PAYMENT         NaN
# 12037  posted                NaN  121.48 -30.75         PAYMENT         NaN
#
#             balance       date gender  age merchant_suburb merchant_state  \
# 5       1705.430054 2018-08-01      M   20             NaN            NaN
# 9        466.579987 2018-08-01      M   40             NaN            NaN
# 10      4348.500000 2018-08-01      M   19             NaN            NaN
# 11      1203.750000 2018-08-01      F   43             NaN            NaN
# 13      4438.160156 2018-08-01      M   23             NaN            NaN
# ...             ...        ...    ...  ...             ...            ...
# 12027  13537.750000 2018-10-31      M   27             NaN            NaN
# 12032  20699.900391 2018-10-31      F   19             NaN            NaN
# 12035   9349.509766 2018-10-31      M   26             NaN            NaN
# 12036  18127.500000 2018-10-31      M   39             NaN            NaN
# 12037  24775.660156 2018-10-31      M   29             NaN            NaN
#
#                extraction  amount     customer_id merchant_long_lat movement
# 5     2018-08-01 02:00:00   163.0  CUS-2688605418               NaN    debit
# 9     2018-08-01 06:00:00    21.0  CUS-2031327464               NaN    debit
# 10    2018-08-01 06:00:00    27.0  CUS-2317998716               NaN    debit
# 11    2018-08-01 06:00:00    29.0  CUS-4123612273               NaN    debit
# 13    2018-08-01 07:00:00    25.0  CUS-1462656821               NaN    debit
# ...                   ...     ...             ...               ...      ...
# 12027 2018-10-31 21:00:00    67.0  CUS-3180318393               NaN    debit
# 12032 2018-10-31 22:00:00    33.0   CUS-883482547               NaN    debit
# 12035 2018-10-31 23:00:00    29.0  CUS-1646621553               NaN    debit
# 12036 2018-10-31 23:00:00    32.0  CUS-1790886359               NaN    debit
# 12037 2018-10-31 23:00:00    39.0   CUS-261674136               NaN    debit
#
# [4326 rows x 16 columns]

# %% [markdown]
# From this it appears that all status = posted have the same NaN values for the equalnull_df we created. For now, we will not be dropping these rows because the values from each row in other columns can still be used for insight. I will create a dataframe where all NaN values are dropped. This will get rid of 4326 rows. out of 12402 rows, nearly 35% of the data.

# %%
df2 = df1.dropna()
df2
# Out:
#            status  card_present_flag       long_lat txn_description  \
# 0      authorized                1.0  153.41 -27.95             POS
# 1      authorized                0.0  153.41 -27.95       SALES-POS
# 2      authorized                1.0  151.23 -33.94             POS
# 3      authorized                1.0  153.10 -27.66       SALES-POS
# 4      authorized                1.0  153.41 -27.95       SALES-POS
# ...           ...                ...            ...             ...
# 12038  authorized                0.0  149.83 -29.47             POS
# 12039  authorized                1.0  151.22 -33.87       SALES-POS
# 12040  authorized                1.0  151.12 -33.89             POS
# 12041  authorized                1.0  144.96 -37.76       SALES-POS
# 12042  authorized                1.0  150.92 -33.77       SALES-POS
#
#                                 merchant_id       balance       date gender  \
# 0      81c48296-73be-44a7-befa-d053f48ce7cd     35.389999 2018-08-01      F
# 1      830a451c-316e-4a6a-bf25-e37caedca49e     21.200001 2018-08-01      F
# 2      835c231d-8cdf-4e96-859d-e9d571760cf0      5.710000 2018-08-01      M
# 3      48514682-c78a-4a88-b0da-2d6302e64673   2117.219971 2018-08-01      F
# 4      b4e02c10-0852-4273-b8fd-7b3395e32eb0     17.950001 2018-08-01      F
# ...                                     ...           ...        ...    ...
# 12038  32aa73dc-b7c2-4161-b14d-6271b96ce792  14054.139648 2018-10-31      F
# 12039  296a0500-8552-48ac-ac81-ec37065b568e   9137.790039 2018-10-31      M
# 12040  e5975ab4-08f7-4725-a369-24cc0e35ed6e  45394.570312 2018-10-31      M
# 12041  af49051a-591d-4b08-bd3c-27730b70ed37  11350.669922 2018-10-31      M
# 12042  f31f4b14-2040-40ec-a120-b141bb274cbd   5517.910156 2018-10-31      M
#
#        age merchant_suburb merchant_state          extraction     amount  \
# 0       26         Ashmore            QLD 2018-08-01 01:01:15  16.250000
# 1       26          Sydney            NSW 2018-08-01 01:13:45  14.190000
# 2       38          Sydney            NSW 2018-08-01 01:26:15   6.420000
# 3       40         Buderim            QLD 2018-08-01 01:38:45  40.900002
# 4       26   Mermaid Beach            QLD 2018-08-01 01:51:15   3.250000
# ...    ...             ...            ...                 ...        ...
# 12038   30        Ringwood            VIC 2018-10-31 23:09:06   9.790000
# 12039   20          Casula            NSW 2018-10-31 23:21:46  63.869999
# 12040   28      Kings Park            NSW 2018-10-31 23:34:25  43.959999
# 12041   69        Oakleigh            VIC 2018-10-31 23:47:05  30.770000
# 12042   31          Mascot            NSW 2018-10-31 23:59:44  22.360001
#
#           customer_id merchant_long_lat movement
# 0      CUS-2487424745     153.38 -27.99    debit
# 1      CUS-2487424745     151.21 -33.87    debit
# 2      CUS-2142601169     151.21 -33.87    debit
# 3      CUS-1614226872     153.05 -26.68    debit
# 4      CUS-2487424745     153.44 -28.06    debit
# ...               ...               ...      ...
# 12038    CUS-55310383     145.23 -37.81    debit
# 12039  CUS-2688605418     150.88 -33.96    debit
# 12040  CUS-2663907001     150.92 -33.74    debit
# 12041  CUS-1388323263     145.09 -37.91    debit
# 12042  CUS-3129499595     151.19 -33.93    debit
#
# [7717 rows x 16 columns]

# %% [markdown]
# #

# %%
# Resetting the index
df2.reset_index(inplace = True)

# %%
df2
# Out:
#       index      status  card_present_flag       long_lat txn_description  \
# 0         0  authorized                1.0  153.41 -27.95             POS
# 1         1  authorized                0.0  153.41 -27.95       SALES-POS
# 2         2  authorized                1.0  151.23 -33.94             POS
# 3         3  authorized                1.0  153.10 -27.66       SALES-POS
# 4         4  authorized                1.0  153.41 -27.95       SALES-POS
# ...     ...         ...                ...            ...             ...
# 7712  12038  authorized                0.0  149.83 -29.47             POS
# 7713  12039  authorized                1.0  151.22 -33.87       SALES-POS
# 7714  12040  authorized                1.0  151.12 -33.89             POS
# 7715  12041  authorized                1.0  144.96 -37.76       SALES-POS
# 7716  12042  authorized                1.0  150.92 -33.77       SALES-POS
#
#                                merchant_id       balance       date gender  \
# 0     81c48296-73be-44a7-befa-d053f48ce7cd     35.389999 2018-08-01      F
# 1     830a451c-316e-4a6a-bf25-e37caedca49e     21.200001 2018-08-01      F
# 2     835c231d-8cdf-4e96-859d-e9d571760cf0      5.710000 2018-08-01      M
# 3     48514682-c78a-4a88-b0da-2d6302e64673   2117.219971 2018-08-01      F
# 4     b4e02c10-0852-4273-b8fd-7b3395e32eb0     17.950001 2018-08-01      F
# ...                                    ...           ...        ...    ...
# 7712  32aa73dc-b7c2-4161-b14d-6271b96ce792  14054.139648 2018-10-31      F
# 7713  296a0500-8552-48ac-ac81-ec37065b568e   9137.790039 2018-10-31      M
# 7714  e5975ab4-08f7-4725-a369-24cc0e35ed6e  45394.570312 2018-10-31      M
# 7715  af49051a-591d-4b08-bd3c-27730b70ed37  11350.669922 2018-10-31      M
# 7716  f31f4b14-2040-40ec-a120-b141bb274cbd   5517.910156 2018-10-31      M
#
#       age merchant_suburb merchant_state          extraction     amount  \
# 0      26         Ashmore            QLD 2018-08-01 01:01:15  16.250000
# 1      26          Sydney            NSW 2018-08-01 01:13:45  14.190000
# 2      38          Sydney            NSW 2018-08-01 01:26:15   6.420000
# 3      40         Buderim            QLD 2018-08-01 01:38:45  40.900002
# 4      26   Mermaid Beach            QLD 2018-08-01 01:51:15   3.250000
# ...   ...             ...            ...                 ...        ...
# 7712   30        Ringwood            VIC 2018-10-31 23:09:06   9.790000
# 7713   20          Casula            NSW 2018-10-31 23:21:46  63.869999
# 7714   28      Kings Park            NSW 2018-10-31 23:34:25  43.959999
# 7715   69        Oakleigh            VIC 2018-10-31 23:47:05  30.770000
# 7716   31          Mascot            NSW 2018-10-31 23:59:44  22.360001
#
#          customer_id merchant_long_lat movement
# 0     CUS-2487424745     153.38 -27.99    debit
# 1     CUS-2487424745     151.21 -33.87    debit
# 2     CUS-2142601169     151.21 -33.87    debit
# 3     CUS-1614226872     153.05 -26.68    debit
# 4     CUS-2487424745     153.44 -28.06    debit
# ...              ...               ...      ...
# 7712    CUS-55310383     145.23 -37.81    debit
# 7713  CUS-2688605418     150.88 -33.96    debit
# 7714  CUS-2663907001     150.92 -33.74    debit
# 7715  CUS-1388323263     145.09 -37.91    debit
# 7716  CUS-3129499595     151.19 -33.93    debit
#
# [7717 rows x 17 columns]

# %% [markdown]
# There are now two dataframes.
#
#     df1 - contains all rows including NaN
#
#     df2 - contains only rows with non NaN values

# %% [markdown]
# Need to save dataframes into csv files so we can call directly and not need to load the entire notebook every time

# %% [markdown]
# # Outliers

# %%
# We can use distplot() to see of data is skewed
sns.distplot(df1['amount'])
# Out:
# <AxesSubplot:xlabel='amount'>

# %%
# Checking another feature
sns.distplot(df1['balance'])
# Out:
# <AxesSubplot:xlabel='balance'>

# %%
# Using a boxplot we can look for outliers in the data
sns.boxplot(x = df1['amount'])
# Out:
# <AxesSubplot:xlabel='amount'>

# %%
# Using a boxplot we can look for outliers in the data
sns.boxplot(x = df1['balance'])
# Out:
# <AxesSubplot:xlabel='balance'>

# %% [markdown]
# #### The data is right skewed when it comes to balance and amount. There are clearly outliers as the boxplots indicate.

# %% [markdown]
# ### Detecting and Removing Outliers

# %%
# importing library
from scipy.stats.mstats import winsorize

# %%
#Tukey's (IQR) Rule
Q1 = df1['amount'].quantile(0.25)
Q3 = df1['amount'].quantile(0.75)
IQR = Q3 - Q1

lower_lim = Q1 - 1.5 * IQR
upper_lim = Q3 + 1.5 * IQR

outliers_15_low = (df1['amount'] < lower_lim)
outliers_15_up = (df1['amount'] > upper_lim)

# %%
df1_clean = df1[~(outliers_15_low | outliers_15_up)]

# %%
sns.boxplot(df1['amount'])
# Out:
# <AxesSubplot:xlabel='amount'>

# %%
# Now for balance
#Tukey's (IQR) Rule
Q1 = df1_clean['balance'].quantile(0.25)
Q3 = df1_clean['balance'].quantile(0.75)
IQR = Q3 - Q1

lower_lim = Q1 - 1.5 * IQR
upper_lim = Q3 + 1.5 * IQR

outliers_15_low = (df1_clean['balance'] < lower_lim)
outliers_15_up = (df1_clean['balance'] > upper_lim)

# %%
df1_clean = df1_clean[~(outliers_15_low | outliers_15_up)]

# %%
sns.boxplot(df1_clean['balance'])
# Out:
# <AxesSubplot:xlabel='balance'>

# %%
# Now for balance
#Tukey's (IQR) Rule
Q1 = df1_clean['balance'].quantile(0.25)
Q3 = df1_clean['balance'].quantile(0.75)
IQR = Q3 - Q1

lower_lim = Q1 - 1.5 * IQR
upper_lim = Q3 + 1.5 * IQR

outliers_15_low = (df1_clean['balance'] < lower_lim)
outliers_15_up = (df1_clean['balance'] > upper_lim)

# %%
df1_clean = df1_clean[~(outliers_15_low | outliers_15_up)]

# %%
sns.boxplot(df1_clean['balance'])
# Out:
# <AxesSubplot:xlabel='balance'>

# %% [markdown]
# # Exploratory Data Analysis on df1
#
#     - Gather some interesting overall insights about the data. For example -- what is the average transaction amount? How many transactions do customers make each month, on average?
#
#     - Segment the dataset by transaction date and time. Visualise transaction volume and spending over the course of an average day or week. Consider the effect of any outliers that may distort your analysis.
#
#     - For a challenge – what insights can you draw from the location information provided in the dataset?
#
#     - Put together 2-3 slides summarising your most interesting findings to ANZ management.

# %%
df1.head()
# Out:
#        status  card_present_flag       long_lat txn_description  \
# 0  authorized                1.0  153.41 -27.95             POS
# 1  authorized                0.0  153.41 -27.95       SALES-POS
# 2  authorized                1.0  151.23 -33.94             POS
# 3  authorized                1.0  153.10 -27.66       SALES-POS
# 4  authorized                1.0  153.41 -27.95       SALES-POS
#
#                             merchant_id      balance       date gender  age  \
# 0  81c48296-73be-44a7-befa-d053f48ce7cd    35.389999 2018-08-01      F   26
# 1  830a451c-316e-4a6a-bf25-e37caedca49e    21.200001 2018-08-01      F   26
# 2  835c231d-8cdf-4e96-859d-e9d571760cf0     5.710000 2018-08-01      M   38
# 3  48514682-c78a-4a88-b0da-2d6302e64673  2117.219971 2018-08-01      F   40
# 4  b4e02c10-0852-4273-b8fd-7b3395e32eb0    17.950001 2018-08-01      F   26
#
#   merchant_suburb merchant_state          extraction     amount  \
# 0         Ashmore            QLD 2018-08-01 01:01:15  16.250000
# 1          Sydney            NSW 2018-08-01 01:13:45  14.190000
# 2          Sydney            NSW 2018-08-01 01:26:15   6.420000
# 3         Buderim            QLD 2018-08-01 01:38:45  40.900002
# 4   Mermaid Beach            QLD 2018-08-01 01:51:15   3.250000
#
#       customer_id merchant_long_lat movement
# 0  CUS-2487424745     153.38 -27.99    debit
# 1  CUS-2487424745     151.21 -33.87    debit
# 2  CUS-2142601169     151.21 -33.87    debit
# 3  CUS-1614226872     153.05 -26.68    debit
# 4  CUS-2487424745     153.44 -28.06    debit

# %% [markdown]
# #### Splitting the extraction column into dates and times

# %%
# year
df1['year'] = df.extraction.dt.year

# month
df1['month'] = df['date'].dt.month_name()

# day
df1['day'] = df.extraction.dt.day

# hour
df1['hour'] = df.extraction.dt.hour

# minute
df1['minute'] = df.extraction.dt.minute

# day_name
df1['day_name'] = df['date'].dt.day_name()

# %%
df1.head()
# Out:
#        status  card_present_flag       long_lat txn_description  \
# 0  authorized                1.0  153.41 -27.95             POS
# 1  authorized                0.0  153.41 -27.95       SALES-POS
# 2  authorized                1.0  151.23 -33.94             POS
# 3  authorized                1.0  153.10 -27.66       SALES-POS
# 4  authorized                1.0  153.41 -27.95       SALES-POS
#
#                             merchant_id      balance       date gender  age  \
# 0  81c48296-73be-44a7-befa-d053f48ce7cd    35.389999 2018-08-01      F   26
# 1  830a451c-316e-4a6a-bf25-e37caedca49e    21.200001 2018-08-01      F   26
# 2  835c231d-8cdf-4e96-859d-e9d571760cf0     5.710000 2018-08-01      M   38
# 3  48514682-c78a-4a88-b0da-2d6302e64673  2117.219971 2018-08-01      F   40
# 4  b4e02c10-0852-4273-b8fd-7b3395e32eb0    17.950001 2018-08-01      F   26
#
#   merchant_suburb merchant_state          extraction     amount  \
# 0         Ashmore            QLD 2018-08-01 01:01:15  16.250000
# 1          Sydney            NSW 2018-08-01 01:13:45  14.190000
# 2          Sydney            NSW 2018-08-01 01:26:15   6.420000
# 3         Buderim            QLD 2018-08-01 01:38:45  40.900002
# 4   Mermaid Beach            QLD 2018-08-01 01:51:15   3.250000
#
#       customer_id merchant_long_lat movement  year   month  day  hour  minute  \
# 0  CUS-2487424745     153.38 -27.99    debit  2018  August    1     1       1
# 1  CUS-2487424745     151.21 -33.87    debit  2018  August    1     1      13
# 2  CUS-2142601169     151.21 -33.87    debit  2018  August    1     1      26
# 3  CUS-1614226872     153.05 -26.68    debit  2018  August    1     1      38
# 4  CUS-2487424745     153.44 -28.06    debit  2018  August    1     1      51
#
#     day_name
# 0  Wednesday
# 1  Wednesday
# 2  Wednesday
# 3  Wednesday
# 4  Wednesday

# %%
# separating the long_lat column into two new columns
#df['long'] = df['long_lat'].apply(lambda x: x.split('-')[0]).astype('float32')
#df['lat'] = df['long_lat'].apply(lambda x: x.split('-')[1]).astype('float32')

# %% [markdown]
# #### We can begin by finding some statistical information for a few columns

# %%
# Finding the mean age, amount (per transaction), balance

df1.describe()
# Out:
#        card_present_flag        balance           age        amount     year  \
# count        7717.000000   12043.000000  12043.000000  12043.000000  12043.0
# mean            0.802644   14704.198242     30.582330    187.933731   2018.0
# std             0.398023   31503.689453     10.046343    592.599426      0.0
# min             0.000000       0.240000     18.000000      0.100000   2018.0
# 25%             1.000000    3158.584961     22.000000     16.000000   2018.0
# 50%             1.000000    6432.009766     28.000000     29.000000   2018.0
# 75%             1.000000   12465.944824     38.000000     53.655001   2018.0
# max             1.000000  267128.531250     78.000000   8835.980469   2018.0
#
#                 day          hour        minute
# count  12043.000000  12043.000000  12043.000000
# mean      15.862908     13.268621     19.009632
# std        8.899598      5.777284     19.879112
# min        1.000000      0.000000      0.000000
# 25%        8.000000      9.000000      0.000000
# 50%       16.000000     13.000000     13.000000
# 75%       24.000000     18.000000     36.000000
# max       31.000000     23.000000     59.000000

# %%
df1.describe()
# Out:
#        card_present_flag        balance           age        amount     year  \
# count        7717.000000   12043.000000  12043.000000  12043.000000  12043.0
# mean            0.802644   14704.198242     30.582330    187.933731   2018.0
# std             0.398023   31503.689453     10.046343    592.599426      0.0
# min             0.000000       0.240000     18.000000      0.100000   2018.0
# 25%             1.000000    3158.584961     22.000000     16.000000   2018.0
# 50%             1.000000    6432.009766     28.000000     29.000000   2018.0
# 75%             1.000000   12465.944824     38.000000     53.655001   2018.0
# max             1.000000  267128.531250     78.000000   8835.980469   2018.0
#
#                 day          hour        minute
# count  12043.000000  12043.000000  12043.000000
# mean      15.862908     13.268621     19.009632
# std        8.899598      5.777284     19.879112
# min        1.000000      0.000000      0.000000
# 25%        8.000000      9.000000      0.000000
# 50%       16.000000     13.000000     13.000000
# 75%       24.000000     18.000000     36.000000
# max       31.000000     23.000000     59.000000

# %%
df1.head()
# Out:
#        status  card_present_flag       long_lat txn_description  \
# 0  authorized                1.0  153.41 -27.95             POS
# 1  authorized                0.0  153.41 -27.95       SALES-POS
# 2  authorized                1.0  151.23 -33.94             POS
# 3  authorized                1.0  153.10 -27.66       SALES-POS
# 4  authorized                1.0  153.41 -27.95       SALES-POS
#
#                             merchant_id      balance       date gender  age  \
# 0  81c48296-73be-44a7-befa-d053f48ce7cd    35.389999 2018-08-01      F   26
# 1  830a451c-316e-4a6a-bf25-e37caedca49e    21.200001 2018-08-01      F   26
# 2  835c231d-8cdf-4e96-859d-e9d571760cf0     5.710000 2018-08-01      M   38
# 3  48514682-c78a-4a88-b0da-2d6302e64673  2117.219971 2018-08-01      F   40
# 4  b4e02c10-0852-4273-b8fd-7b3395e32eb0    17.950001 2018-08-01      F   26
#
#   merchant_suburb merchant_state          extraction     amount  \
# 0         Ashmore            QLD 2018-08-01 01:01:15  16.250000
# 1          Sydney            NSW 2018-08-01 01:13:45  14.190000
# 2          Sydney            NSW 2018-08-01 01:26:15   6.420000
# 3         Buderim            QLD 2018-08-01 01:38:45  40.900002
# 4   Mermaid Beach            QLD 2018-08-01 01:51:15   3.250000
#
#       customer_id merchant_long_lat movement  year   month  day  hour  minute  \
# 0  CUS-2487424745     153.38 -27.99    debit  2018  August    1     1       1
# 1  CUS-2487424745     151.21 -33.87    debit  2018  August    1     1      13
# 2  CUS-2142601169     151.21 -33.87    debit  2018  August    1     1      26
# 3  CUS-1614226872     153.05 -26.68    debit  2018  August    1     1      38
# 4  CUS-2487424745     153.44 -28.06    debit  2018  August    1     1      51
#
#     day_name
# 0  Wednesday
# 1  Wednesday
# 2  Wednesday
# 3  Wednesday
# 4  Wednesday

# %%
# Checking the total of the all transctions
avg_amount = df1['amount'].mean()
print(f"The average transaction amount {avg_amount}")
# Out:
# The average transaction amount 187.93373107910156

# %%
# Transactions per month
month_counts = df1['month'].value_counts().to_frame()
month_counts.rename(columns={'month': 'value_counts'}, inplace=True)
month_counts
# Out:
#            value_counts
# October            4087
# September          4013
# August             3943

# %%
# Transactions per merchant_suburb
merchant_suburb_counts = df1['merchant_suburb_counts'].value_counts().to_frame()
merchant_suburb_counts.rename(columns={'merchant_suburb_counts': 'value_counts'}, inplace=True)
merchant_suburb_counts
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Python\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2888             try:
# -> 2889                 return self._engine.get_loc(casted_key)
#    2890             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'merchant_suburb_counts'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-57-1970ccd802f1> in <module>
#       1 # Transactions per merchant_suburb
# ----> 2 merchant_suburb_counts = df1['merchant_suburb_counts'].value_counts().to_frame()
#       3 merchant_suburb_counts.rename(columns={'merchant_suburb_counts': 'value_counts'}, inplace=True)
#       4 merchant_suburb_counts
#
# C:\Python\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# C:\Python\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2889                 return self._engine.get_loc(casted_key)
#    2890             except KeyError as err:
# -> 2891                 raise KeyError(key) from err
#    2892
#    2893         if tolerance is not None:
#
# KeyError: 'merchant_suburb_counts'

# %%
# transaction counts by gender
gender_counts = df1['gender'].value_counts().to_frame()
gender_counts.rename(columns={'gender': 'value_counts'}, inplace=True)
gender_counts

# %% [markdown]
# ## Data Visualization

# %%
df1.head()
# Out:
#        status  card_present_flag       long_lat txn_description  \
# 0  authorized                1.0  153.41 -27.95             POS
# 1  authorized                0.0  153.41 -27.95       SALES-POS
# 2  authorized                1.0  151.23 -33.94             POS
# 3  authorized                1.0  153.10 -27.66       SALES-POS
# 4  authorized                1.0  153.41 -27.95       SALES-POS
#
#                             merchant_id      balance       date gender  age  \
# 0  81c48296-73be-44a7-befa-d053f48ce7cd    35.389999 2018-08-01      F   26
# 1  830a451c-316e-4a6a-bf25-e37caedca49e    21.200001 2018-08-01      F   26
# 2  835c231d-8cdf-4e96-859d-e9d571760cf0     5.710000 2018-08-01      M   38
# 3  48514682-c78a-4a88-b0da-2d6302e64673  2117.219971 2018-08-01      F   40
# 4  b4e02c10-0852-4273-b8fd-7b3395e32eb0    17.950001 2018-08-01      F   26
#
#   merchant_suburb merchant_state          extraction     amount  \
# 0         Ashmore            QLD 2018-08-01 01:01:15  16.250000
# 1          Sydney            NSW 2018-08-01 01:13:45  14.190000
# 2          Sydney            NSW 2018-08-01 01:26:15   6.420000
# 3         Buderim            QLD 2018-08-01 01:38:45  40.900002
# 4   Mermaid Beach            QLD 2018-08-01 01:51:15   3.250000
#
#       customer_id merchant_long_lat movement  year   month  day  hour  minute  \
# 0  CUS-2487424745     153.38 -27.99    debit  2018  August    1     1       1
# 1  CUS-2487424745     151.21 -33.87    debit  2018  August    1     1      13
# 2  CUS-2142601169     151.21 -33.87    debit  2018  August    1     1      26
# 3  CUS-1614226872     153.05 -26.68    debit  2018  August    1     1      38
# 4  CUS-2487424745     153.44 -28.06    debit  2018  August    1     1      51
#
#     day_name
# 0  Wednesday
# 1  Wednesday
# 2  Wednesday
# 3  Wednesday
# 4  Wednesday

# %%
#Count of transactions by age

plt.figure(figsize=(12, 7))
sns.countplot(df['age'], edgecolor='black',linewidth=2)  #double bar graph for age of investments with hue as gender.
plt.title("Count of transactions by age")
plt.figure(figsize=(12, 7))
plt.show()

# %%
# Count of transactions by age and gender

plt.figure(figsize=(12, 7))
sns.countplot(df['age'],hue=df['gender'], edgecolor='black',linewidth=2)  #double bar graph for age of investments with hue as gender.
plt.title("Count of transactions by age")
plt.show()

# %%
# Count of transactions per state

sns.countplot(df['merchant_state'],palette="Set3",linewidth=2,edgecolor='black')
plt.title('Count of Transactions Per State')
plt.xticks(rotation = 90)
plt.show()
