# %% [markdown]
# ## This is dividend yield data I downloaded from TD Ameritrade
#
# I'm still learning to play around with pandas and plotting.
#
# - Goals
#   - Properly load the csv file
#   - clean the df if needed
#   - group by exchange
#   - find the max and min yield for each exchange
#   - plot data using histograms
#   - bin the data properly
#   - use bin_edges to correctly plot

# %%
# loading in the libraries

import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sb

# %%
# Loading in the dataframe from csv

df = pd.read_excel('dividend_yield.xlsx')
df
# Out:
#       Symbol                     Company Name Market Capitalization  \
# 0     AAIC-B  Arlington Asset Investment Corp                    --
# 1     AAIC-C  Arlington Asset Investment Corp                    --
# 2        AAT       American Assets Trust, Inc            2343290000
# 3       AATC      Autoscope Technologies Corp              43955730
# 4         AB     Alliancebernstein Holding LP            5228993510
# ...      ...                              ...                   ...
# 1280   XOMAP                        XOMA Corp                    --
# 1281     XRX              Xerox Holdings Corp            3708939080
# 1282  YCBD-A                        cbdMD Inc                    --
# 1283      YY                   JOYY Inc (ADR)            4998318750
# 1284     ZTR     Virtus Total Return Fund Inc             461244700
#
#                       Sector                                        Industry  \
# 0                 Financials  Mortgage Real Estate Investment Trusts (REITs)
# 1                 Financials  Mortgage Real Estate Investment Trusts (REITs)
# 2                Real Estate    Equity Real Estate Investment Trusts (REITs)
# 3     Information Technology  Electronic Equipment, Instruments & Components
# 4                 Financials                                 Capital Markets
# ...                      ...                                             ...
# 1280             Health Care                                   Biotechnology
# 1281  Information Technology      Technology Hardware, Storage & Peripherals
# 1282             Health Care                                 Pharmaceuticals
# 1283  Communication Services                    Interactive Media & Services
# 1284                     NaN                                             NaN
#
#       Dividend Yield     Beta
# 0           0.069930       --
# 1           0.081522       --
# 2           0.030542  1.26403
# 3           0.058182  1.17708
# 4           0.065887  1.42399
# ...              ...      ...
# 1280        0.081398       --
# 1281        0.047170  1.81144
# 1282        0.112258       --
# 1283        0.031145  0.85731
# 1284        0.097959  1.21769
#
# [1285 rows x 7 columns]

# %%
# dropping the Company Name
df1 = df
df1.drop('Company Name', axis = 1, inplace = True)

# %%
df
# Out:
#       Symbol Market Capitalization                  Sector  \
# 0     AAIC-B                    --              Financials
# 1     AAIC-C                    --              Financials
# 2        AAT            2343290000             Real Estate
# 3       AATC              43955730  Information Technology
# 4         AB            5228993510              Financials
# ...      ...                   ...                     ...
# 1280   XOMAP                    --             Health Care
# 1281     XRX            3708939080  Information Technology
# 1282  YCBD-A                    --             Health Care
# 1283      YY            4998318750  Communication Services
# 1284     ZTR             461244700                     NaN
#
#                                             Industry  Dividend Yield     Beta
# 0     Mortgage Real Estate Investment Trusts (REITs)        0.069930       --
# 1     Mortgage Real Estate Investment Trusts (REITs)        0.081522       --
# 2       Equity Real Estate Investment Trusts (REITs)        0.030542  1.26403
# 3     Electronic Equipment, Instruments & Components        0.058182  1.17708
# 4                                    Capital Markets        0.065887  1.42399
# ...                                              ...             ...      ...
# 1280                                   Biotechnology        0.081398       --
# 1281      Technology Hardware, Storage & Peripherals        0.047170  1.81144
# 1282                                 Pharmaceuticals        0.112258       --
# 1283                    Interactive Media & Services        0.031145  0.85731
# 1284                                             NaN        0.097959  1.21769
#
# [1285 rows x 6 columns]

# %%
# shortening some column headers

df1.rename({'Market Capitalization': 'marketcap', 'Dividend Yield': 'divyield'}, axis = 1, inplace = True)
df1
# Out:
#       Symbol   marketcap                  Sector  \
# 0     AAIC-B          --              Financials
# 1     AAIC-C          --              Financials
# 2        AAT  2343290000             Real Estate
# 3       AATC    43955730  Information Technology
# 4         AB  5228993510              Financials
# ...      ...         ...                     ...
# 1280   XOMAP          --             Health Care
# 1281     XRX  3708939080  Information Technology
# 1282  YCBD-A          --             Health Care
# 1283      YY  4998318750  Communication Services
# 1284     ZTR   461244700                     NaN
#
#                                             Industry  divyield     Beta
# 0     Mortgage Real Estate Investment Trusts (REITs)  0.069930       --
# 1     Mortgage Real Estate Investment Trusts (REITs)  0.081522       --
# 2       Equity Real Estate Investment Trusts (REITs)  0.030542  1.26403
# 3     Electronic Equipment, Instruments & Components  0.058182  1.17708
# 4                                    Capital Markets  0.065887  1.42399
# ...                                              ...       ...      ...
# 1280                                   Biotechnology  0.081398       --
# 1281      Technology Hardware, Storage & Peripherals  0.047170  1.81144
# 1282                                 Pharmaceuticals  0.112258       --
# 1283                    Interactive Media & Services  0.031145  0.85731
# 1284                                             NaN  0.097959  1.21769
#
# [1285 rows x 6 columns]

# %%
# replacing '--' with '0'
df1['marketcap'].replace('--', '0',inplace = True)
df1
# Out:
#       Symbol   marketcap                  Sector  \
# 0     AAIC-B           0              Financials
# 1     AAIC-C           0              Financials
# 2        AAT  2343290000             Real Estate
# 3       AATC    43955730  Information Technology
# 4         AB  5228993510              Financials
# ...      ...         ...                     ...
# 1280   XOMAP           0             Health Care
# 1281     XRX  3708939080  Information Technology
# 1282  YCBD-A           0             Health Care
# 1283      YY  4998318750  Communication Services
# 1284     ZTR   461244700                     NaN
#
#                                             Industry  divyield     Beta
# 0     Mortgage Real Estate Investment Trusts (REITs)  0.069930       --
# 1     Mortgage Real Estate Investment Trusts (REITs)  0.081522       --
# 2       Equity Real Estate Investment Trusts (REITs)  0.030542  1.26403
# 3     Electronic Equipment, Instruments & Components  0.058182  1.17708
# 4                                    Capital Markets  0.065887  1.42399
# ...                                              ...       ...      ...
# 1280                                   Biotechnology  0.081398       --
# 1281      Technology Hardware, Storage & Peripherals  0.047170  1.81144
# 1282                                 Pharmaceuticals  0.112258       --
# 1283                    Interactive Media & Services  0.031145  0.85731
# 1284                                             NaN  0.097959  1.21769
#
# [1285 rows x 6 columns]

# %%
# checking the dtypes 
df1.dtypes
# Out:
# Symbol        object
# marketcap     object
# Sector        object
# Industry      object
# divyield     float64
# Beta          object
# dtype: object

# %%
# converting the dtypes to int if needed

df1['market_cap'] = df1['marketcap'].astype(object).astype(str).astype(np.int64)

# %%
df1.head()
# Out:
#    Symbol   marketcap                  Sector  \
# 0  AAIC-B           0              Financials
# 1  AAIC-C           0              Financials
# 2     AAT  2343290000             Real Estate
# 3    AATC    43955730  Information Technology
# 4      AB  5228993510              Financials
#
#                                          Industry  divyield     Beta  \
# 0  Mortgage Real Estate Investment Trusts (REITs)  0.069930       --
# 1  Mortgage Real Estate Investment Trusts (REITs)  0.081522       --
# 2    Equity Real Estate Investment Trusts (REITs)  0.030542  1.26403
# 3  Electronic Equipment, Instruments & Components  0.058182  1.17708
# 4                                 Capital Markets  0.065887  1.42399
#
#    market_cap
# 0           0
# 1           0
# 2  2343290000
# 3    43955730
# 4  5228993510

# %%
df1.dtypes
# Out:
# Symbol         object
# marketcap      object
# Sector         object
# Industry       object
# divyield      float64
# Beta           object
# market_cap      int64
# dtype: object

# %%
# dropping the extra marketcap column
df1.drop('marketcap', axis = 1, inplace = True )

# %% [markdown]
# #

# %%
df1
# Out:
#       Symbol                  Sector  \
# 0     AAIC-B              Financials
# 1     AAIC-C              Financials
# 2        AAT             Real Estate
# 3       AATC  Information Technology
# 4         AB              Financials
# ...      ...                     ...
# 1280   XOMAP             Health Care
# 1281     XRX  Information Technology
# 1282  YCBD-A             Health Care
# 1283      YY  Communication Services
# 1284     ZTR                     NaN
#
#                                             Industry  divyield     Beta  \
# 0     Mortgage Real Estate Investment Trusts (REITs)  0.069930       --
# 1     Mortgage Real Estate Investment Trusts (REITs)  0.081522       --
# 2       Equity Real Estate Investment Trusts (REITs)  0.030542  1.26403
# 3     Electronic Equipment, Instruments & Components  0.058182  1.17708
# 4                                    Capital Markets  0.065887  1.42399
# ...                                              ...       ...      ...
# 1280                                   Biotechnology  0.081398       --
# 1281      Technology Hardware, Storage & Peripherals  0.047170  1.81144
# 1282                                 Pharmaceuticals  0.112258       --
# 1283                    Interactive Media & Services  0.031145  0.85731
# 1284                                             NaN  0.097959  1.21769
#
#       market_cap
# 0              0
# 1              0
# 2     2343290000
# 3       43955730
# 4     5228993510
# ...          ...
# 1280           0
# 1281  3708939080
# 1282           0
# 1283  4998318750
# 1284   461244700
#
# [1285 rows x 6 columns]

# %%
# Dropping any NaN values mainly from sector and industry as not knowing these will not help much
df1.dropna(inplace = True)

# %%
df1
# Out:
#       Symbol                  Sector  \
# 0     AAIC-B              Financials
# 1     AAIC-C              Financials
# 2        AAT             Real Estate
# 3       AATC  Information Technology
# 4         AB              Financials
# ...      ...                     ...
# 1279     XOM                  Energy
# 1280   XOMAP             Health Care
# 1281     XRX  Information Technology
# 1282  YCBD-A             Health Care
# 1283      YY  Communication Services
#
#                                             Industry  divyield     Beta  \
# 0     Mortgage Real Estate Investment Trusts (REITs)  0.069930       --
# 1     Mortgage Real Estate Investment Trusts (REITs)  0.081522       --
# 2       Equity Real Estate Investment Trusts (REITs)  0.030542  1.26403
# 3     Electronic Equipment, Instruments & Components  0.058182  1.17708
# 4                                    Capital Markets  0.065887  1.42399
# ...                                              ...       ...      ...
# 1279                     Oil, Gas & Consumable Fuels  0.064337  1.41824
# 1280                                   Biotechnology  0.081398       --
# 1281      Technology Hardware, Storage & Peripherals  0.047170  1.81144
# 1282                                 Pharmaceuticals  0.112258       --
# 1283                    Interactive Media & Services  0.031145  0.85731
#
#         market_cap
# 0                0
# 1                0
# 2       2343290000
# 3         43955730
# 4       5228993510
# ...            ...
# 1279  229586121490
# 1280             0
# 1281    3708939080
# 1282             0
# 1283    4998318750
#
# [863 rows x 6 columns]

# %%
# meant to replace '--' in Beta
# accidentally stumbled upon the fact that I could have omitted the column name[marketcap] in an earlier step 
# and I would have replaced all values '--' in the entire dataframe. Nice.
df1.replace('--','0',inplace = True)

# %%
df1
# Out:
#       Symbol                  Sector  \
# 0     AAIC-B              Financials
# 1     AAIC-C              Financials
# 2        AAT             Real Estate
# 3       AATC  Information Technology
# 4         AB              Financials
# ...      ...                     ...
# 1279     XOM                  Energy
# 1280   XOMAP             Health Care
# 1281     XRX  Information Technology
# 1282  YCBD-A             Health Care
# 1283      YY  Communication Services
#
#                                             Industry  divyield     Beta  \
# 0     Mortgage Real Estate Investment Trusts (REITs)  0.069930        0
# 1     Mortgage Real Estate Investment Trusts (REITs)  0.081522        0
# 2       Equity Real Estate Investment Trusts (REITs)  0.030542  1.26403
# 3     Electronic Equipment, Instruments & Components  0.058182  1.17708
# 4                                    Capital Markets  0.065887  1.42399
# ...                                              ...       ...      ...
# 1279                     Oil, Gas & Consumable Fuels  0.064337  1.41824
# 1280                                   Biotechnology  0.081398        0
# 1281      Technology Hardware, Storage & Peripherals  0.047170  1.81144
# 1282                                 Pharmaceuticals  0.112258        0
# 1283                    Interactive Media & Services  0.031145  0.85731
#
#         market_cap
# 0                0
# 1                0
# 2       2343290000
# 3         43955730
# 4       5228993510
# ...            ...
# 1279  229586121490
# 1280             0
# 1281    3708939080
# 1282             0
# 1283    4998318750
#
# [863 rows x 6 columns]

# %%
# converting beta to float64 and creating a new column
df1['beta'] = df1['Beta'].astype(object).astype(str).astype(np.float64)

# dropping the old column
df1.drop('Beta', axis = 1, inplace = True)

# loading df to make sure we are moving forward
df1
# Out:
#       Symbol                  Sector  \
# 0     AAIC-B              Financials
# 1     AAIC-C              Financials
# 2        AAT             Real Estate
# 3       AATC  Information Technology
# 4         AB              Financials
# ...      ...                     ...
# 1279     XOM                  Energy
# 1280   XOMAP             Health Care
# 1281     XRX  Information Technology
# 1282  YCBD-A             Health Care
# 1283      YY  Communication Services
#
#                                             Industry  divyield    market_cap  \
# 0     Mortgage Real Estate Investment Trusts (REITs)  0.069930             0
# 1     Mortgage Real Estate Investment Trusts (REITs)  0.081522             0
# 2       Equity Real Estate Investment Trusts (REITs)  0.030542    2343290000
# 3     Electronic Equipment, Instruments & Components  0.058182      43955730
# 4                                    Capital Markets  0.065887    5228993510
# ...                                              ...       ...           ...
# 1279                     Oil, Gas & Consumable Fuels  0.064337  229586121490
# 1280                                   Biotechnology  0.081398             0
# 1281      Technology Hardware, Storage & Peripherals  0.047170    3708939080
# 1282                                 Pharmaceuticals  0.112258             0
# 1283                    Interactive Media & Services  0.031145    4998318750
#
#          beta
# 0     0.00000
# 1     0.00000
# 2     1.26403
# 3     1.17708
# 4     1.42399
# ...       ...
# 1279  1.41824
# 1280  0.00000
# 1281  1.81144
# 1282  0.00000
# 1283  0.85731
#
# [863 rows x 6 columns]

# %%
# checking the dtypes again
df1.dtypes
# Out:
# Symbol         object
# Sector         object
# Industry       object
# divyield      float64
# market_cap      int64
# beta          float64
# dtype: object

# %%
for i in df1.columns:
    cat_num = df1[i].value_counts()
    print("Graph for %s: total = %d" % (i, len(cat_num)))
    chart = sb.barplot(x = cat_num.index , y = cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# Graph for Symbol: total = 863
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-48412345a792> in <module>
#       4     chart = sb.barplot(x = cat_num.index , y = cat_num)
#       5     chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
# ----> 6     plt.show()
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in show(*args, **kwargs)
#     351     """
#     352     _warn_if_gui_out_of_main_thread()
# --> 353     return _backend_mod.show(*args, **kwargs)
#     354
#     355
#
# ~\anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      39     try:
#      40         for figure_manager in Gcf.get_all_fig_managers():
# ---> 41             display(
#      42                 figure_manager.canvas.figure,
#      43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# ~\anaconda3\lib\site-packages\IPython\core\display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     311             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     312         else:
# --> 313             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     314             if not format_dict:
#     315                 # nothing to display (e.g. _ipython_display_ took over)
#
# ~\anaconda3\lib\site-packages\IPython\core\formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# ~\anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# ~\anaconda3\lib\site-packages\IPython\core\formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# ~\anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~\anaconda3\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~\anaconda3\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2193                         self.figure.draw(renderer)
#    2194
# -> 2195                     bbox_inches = self.figure.get_tightbbox(
#    2196                         renderer, bbox_extra_artists=bbox_extra_artists)
#    2197                     if pad_inches is None:
#
# ~\anaconda3\lib\site-packages\matplotlib\figure.py in get_tightbbox(self, renderer, bbox_extra_artists)
#    2504
#    2505         for a in artists:
# -> 2506             bbox = a.get_tightbbox(renderer)
#    2507             if bbox is not None and (bbox.width != 0 or bbox.height != 0):
#    2508                 bb.append(bbox)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists, for_layout_only)
#    4151             if self.xaxis.get_visible():
#    4152                 try:
# -> 4153                     bb_xaxis = self.xaxis.get_tightbbox(
#    4154                         renderer, for_layout_only=for_layout_only)
#    4155                 except TypeError:
#
# ~\anaconda3\lib\site-packages\matplotlib\axis.py in get_tightbbox(self, renderer, for_layout_only)
#    1109         ticks_to_draw = self._update_ticks()
#    1110
# -> 1111         self._update_label_position(renderer)
#    1112
#    1113         # go back to just this axis's tick labels
#
# ~\anaconda3\lib\site-packages\matplotlib\axis.py in _update_label_position(self, renderer)
#    2059         # get bounding boxes for this axis and any siblings
#    2060         # that have been set by `fig.align_xlabels()`
# -> 2061         bboxes, bboxes2 = self._get_tick_boxes_siblings(renderer=renderer)
#    2062
#    2063         x, y = self.label.get_position()
#
# ~\anaconda3\lib\site-packages\matplotlib\axis.py in _get_tick_boxes_siblings(self, renderer)
#    2044         for nn, axx in enumerate(grp.get_siblings(self.axes)):
#    2045             ticks_to_draw = axx.xaxis._update_ticks()
# -> 2046             tlb, tlb2 = axx.xaxis._get_tick_bboxes(ticks_to_draw, renderer)
#    2047             bboxes.extend(tlb)
#    2048             bboxes2.extend(tlb2)
#
# ~\anaconda3\lib\site-packages\matplotlib\axis.py in _get_tick_bboxes(self, ticks, renderer)
#    1089     def _get_tick_bboxes(self, ticks, renderer):
#    1090         """Return lists of bboxes for ticks' label1's and label2's."""
# -> 1091         return ([tick.label1.get_window_extent(renderer)
#    1092                  for tick in ticks if tick.label1.get_visible()],
#    1093                 [tick.label2.get_window_extent(renderer)
#
# ~\anaconda3\lib\site-packages\matplotlib\axis.py in <listcomp>(.0)
#    1089     def _get_tick_bboxes(self, ticks, renderer):
#    1090         """Return lists of bboxes for ticks' label1's and label2's."""
# -> 1091         return ([tick.label1.get_window_extent(renderer)
#    1092                  for tick in ticks if tick.label1.get_visible()],
#    1093                 [tick.label2.get_window_extent(renderer)
#
# ~\anaconda3\lib\site-packages\matplotlib\text.py in get_window_extent(self, renderer, dpi)
#     900
#     901         with cbook._setattr_cm(self.figure, dpi=dpi):
# --> 902             bbox, info, descent = self._get_layout(self._renderer)
#     903             x, y = self.get_unitless_position()
#     904             x, y = self.get_transform().transform((x, y))
#
# ~\anaconda3\lib\site-packages\matplotlib\text.py in _get_layout(self, renderer)
#     285
#     286         # Full vertical extent of font, including ascenders and descenders:
# --> 287         _, lp_h, lp_d = renderer.get_text_width_height_descent(
#     288             "lp", self._fontproperties,
#     289             ismath="TeX" if self.get_usetex() else False)
#
# ~\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in get_text_width_height_descent(self, s, prop, ismath)
#     235
#     236         flags = get_hinting_flag()
# --> 237         font = self._get_agg_font(prop)
#     238         font.set_text(s, 0.0, flags=flags)
#     239         w, h = font.get_width_height()  # width and height of unrotated string
#
# ~\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in _get_agg_font(self, prop)
#     270         Get the font for text instance t, caching for efficiency
#     271         """
# --> 272         fname = findfont(prop)
#     273         font = get_font(fname)
#     274
#
# ~\anaconda3\lib\site-packages\matplotlib\font_manager.py in findfont(self, prop, fontext, directory, fallback_to_default, rebuild_if_missing)
#    1312             prop, fontext, directory, fallback_to_default, rebuild_if_missing,
#    1313             rc_params)
# -> 1314         return os.path.realpath(filename)
#    1315
#    1316     @lru_cache()
#
# ~\anaconda3\lib\ntpath.py in realpath(path)
#     645             path = join(cwd, path)
#     646         try:
# --> 647             path = _getfinalpathname(path)
#     648             initial_winerror = 0
#     649         except OSError as ex:
#
# KeyboardInterrupt:

# %%
x = 'Sector'
y = 'divyield'

sb.barplot(x,y, data = df1)
# Out:
# C:\Users\Aaron\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Sector', ylabel='divyield'>
